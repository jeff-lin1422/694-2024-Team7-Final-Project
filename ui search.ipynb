# %%
import warnings
from flask import  Flask, jsonify, request, render_template
# Suppress all warnings
warnings.filterwarnings("ignore")

from Cache_Load_Data import *

# Restore warnings to default behavior
warnings.resetwarnings()

app = Flask(__name__)
# Out:
# Connected to MySQL Server version  8.0.36
# [NbConvertApp] Converting notebook MySQL_Load_Data.ipynb to script
# [NbConvertApp] Writing 3855 bytes to MySQL_Load_Data.py
# Number of documents: 112036
# found
# [['Sat Apr 25 12:39:47 +0000 2020', 1254027325475258368, 'RT elmundociencia: Los españoles creen que la "responsabilidad ciudadana" es el factor más importante para controlar la epidemia de corona…', 'Jimenezlosantos', 1, 2, 'es', 0, 0, None, [], False], ['Sat Apr 25 12:30:00 +0000 2020', 1254024861158002691, 'Al 24 de abril, Puebla ocupa el séptimo lugar nacional de los estados con más casos confirmados de coronavirus en M… https://t.co/8HjnFS6Uq0', 'El_Universal_Mx', 0, 0, 'es', 0, 0, None, [], False], ['Sat Apr 25 12:30:00 +0000 2020', 1254024861204328453, 'हमारे देश के वह न्यूज़ चैनल और एंकर \n#Corona से भी ज्यादा खतरनाक हैं जो इसे सांप्रदायिक रंग दे रहे है. कहते हैं कि… https://t.co/aGDQ7Aoe4S', 'nlhindi', 0, 0, 'hi', 0, 0, None, ['Corona'], False], ['Sat Apr 25 12:30:00 +0000 2020', 1254024861866790912, 'कोरोना संकट में ऐसे मनाएं रमजान का त्योहार, बस ध्यान रखें ये जरूरी बातें... \nhttps://t.co/RbEuNR2O1G\n\n#CoronaVirus… https://t.co/gRniFHMJZB', 'punjabkesari', 0, 0, 'hi', 0, 0, None, ['CoronaVirus'], False], ['Sat Apr 25 12:30:00 +0000 2020', 1254024861715816449, 'வீட்டிலேயே இருப்போம் !\n\n#SunNews #Corona #CoronaVirus #Covid19 #Pandemic #Outbreak #stayhome #stayhomestaysafe… https://t.co/A75ae780OT', 'sunnewstamil', 0, 0, 'ta', 0, 0, None, ['SunNews', 'Corona', 'CoronaVirus', 'Covid19', 'Pandemic', 'Outbreak', 'stayhome', 'stayhomestaysafe'], False]]
# [['Sat Apr 04 15:56:50 +0000 2020', 'रामदेव ने पूरी दुनिया से कहा- चीन का किया जाए बहिष्कार\nhttps://t.co/t4V5gnLhuq', 21517, 4259], ['Wed Apr 22 06:46:51 +0000 2020', 'कोरोना से जंग में पूरी दुनिया ने माना पीएम मोदी की ताकत का लोहा, US सर्वे में टॉप रैंक\n#coronavirus\nhttps://t.co/QvYliTGixR', 14119, 1858], ['Fri Apr 24 14:00:05 +0000 2020', 'इलाहाबाद यूनिवर्सिटी के प्रोफेसर मोहम्मद शाहिद को सस्पेंड किया गया \n#UttarPradesh #TablighiJamat \nhttps://t.co/5u5EIZi1zr', 2921, 333], ['Thu Apr 23 16:49:10 +0000 2020', 'राहुल गांधी ने फिर उठाया दिहाड़ी मजदूरों का मुद्दा #lockdown \nhttps://t.co/1bNZ6BlbQD', 2011, 252], ['Sat Apr 25 05:19:58 +0000 2020', 'राहुल के बाद पूर्व प्रधानमंत्री डॉ मनमोहन सिंह भी डीए कटौती के विरोध में | @patelanandk \n\nhttps://t.co/fWXaGCV7pk', 1909, 243], ['Fri Apr 24 12:20:51 +0000 2020', 'संक्रमित कपड़ा डालकर नाई ने की लोगों की हजामत, गांव में फैल गया कोरोना... \n#MadhyaPradesh #Coronavirus \nhttps://t.co/QLvNPTYtK7', 1823, 415], ['Sat Apr 25 05:08:00 +0000 2020', 'महाराष्ट्र में छिपे हुए सबसे ज्यादा तबलीगी जमाती | @MunishPandeyy \n\nhttps://t.co/UNBw9noElT', 1472, 271], ['Wed Apr 22 12:08:44 +0000 2020', '#UttarPradesh: बीजेपी नेता ने #lockdown में कराया क्रिकेट मैच\n(@ShivendraAajtak)\n\nhttps://t.co/3kzdmoxgvu', 1093, 249], ['Sat Apr 25 08:09:11 +0000 2020', '#Lockdown :  गृह मंत्रालय के मुताबिक देश भर में शराब की दुकानें अगले आदेश तक बंद ही रहेंगी | @kamaljitsandhu \n\nhttps://t.co/mQQzvzB7rx', 849, 68], ['Sat Apr 25 09:57:07 +0000 2020', 'कपिल सिब्बल का मोदी सरकार पर वार!\n#Politics\nhttps://t.co/e8xYSfUYOH', 548, 59]]
# [['Sat Apr 25 12:21:44 +0000 2020', 'RT @viewcenterpod: Catch up on latest episode of THE VIEWING CENTER PODCAST where we discussed\n\n-The Coronavirus pandemic in Nigeria \n- TAC…', 'Vikteneus', 0, 0, 'en', 0, 0, None, [], True], ['Sat Apr 25 12:22:33 +0000 2020', 'RT @viewcenterpod: Catch up on latest episode of THE VIEWING CENTER PODCAST where we discussed\n\n-The Coronavirus pandemic in Nigeria \n- TAC…', 'hardeyshurlar1', 0, 0, 'en', 0, 0, None, [], True], ['Sat Apr 25 13:05:41 +0000 2020', 'RT @viewcenterpod: Catch up on latest episode of THE VIEWING CENTER PODCAST where we discussed\n\n-The Coronavirus pandemic in Nigeria \n- TAC…', 'Omegsb', 0, 0, 'en', 0, 0, None, [], True], ['Sat Apr 25 13:34:42 +0000 2020', 'RT @viewcenterpod: Catch up on latest episode of THE VIEWING CENTER PODCAST where we discussed\n\n-The Coronavirus pandemic in Nigeria \n- TAC…', '_KHAAMA_', 0, 0, 'en', 0, 0, None, [], True]]
# Sat Apr 25 12:30:00 +0000 2020
# Sat Apr 25 12:40:00 +0000 2020
# dettol
# [{'_id': ObjectId('662a60beb8182f1f264c792f'), 'created_at': 'Sat Apr 25 12:35:34 +0000 2020', 'retweeted_id': 0, 'og_tweet_id': 1254026262344957954, 'text': 'I see news that some Americans indeed ingested household cleaners like Lysol, Dettol and Zoflora. Just because POTU… https://t.co/JDvxDtYtlI', 'screen_name': 'hunter_mufc', 'retweet_count': 0, 'favorite_count': 0, 'lang': 'en', 'quote_count': 0, 'reply_count': 0, 'media': None, 'hashtags': [], 'is_retweet': False}, {'_id': ObjectId('662a60beb8182f1f264c78d0'), 'created_at': 'Sat Apr 25 12:35:27 +0000 2020', 'retweeted_id': 0, 'og_tweet_id': 1254026232255123457, 'text': '@CNN After drinking #Dettol  #Corona #Covid_19 #GOP https://t.co/4X9TDrRjOV', 'screen_name': 'EuroP_Media', 'retweet_count': 0, 'favorite_count': 0, 'lang': 'en', 'quote_count': 0, 'reply_count': 0, 'media': 'http://pbs.twimg.com/media/EWcyNcsXsAYMuBq.jpg', 'hashtags': ['Dettol', 'Corona', 'Covid_19', 'GOP'], 'is_retweet': False}]
# {'_id': 'نصر_الله'}
# {'_id': 'KGFChapter2'}
# {'_id': 'Telemedicine'}
# {'_id': 'エアロゾル'}
# {'_id': 'Tegnell'}
# {'_id': 'electronicmusic'}
# {'_id': 'Initiative'}
# {'_id': 'foracorona'}
# {'_id': 'huurwoningen'}
# {'_id': 'geisterspiele'}
# {'_id': 'world'}
# {'_id': 'ARAL'}
# {'_id': 'WE_eiSos'}
# {'_id': 'Migrant'}
# {'_id': 'CRY'}
# {'_id': 'problem1'}
# {'_id': 'sewing'}
# {'_id': 'Linken'}
# {'_id': 'சண்டிகரில்'}
# {'_id': 'jokowi'}
# {'_id': 'لاتجرح_صيامك'}
# {'_id': 'NOvid'}
# {'_id': 'INQUINAMENTO'}
# {'_id': 'simoneEsimariaLive'}
# {'_id': 'coronapocalypse'}
# {'_id': 'Bremer'}
# {'_id': 'ShutDownPolimerTv'}
# {'_id': 'Marco'}
# {'_id': 'ThaharJa'}
# {'_id': 'Petition'}
# {'_id': 'απαγορευση_κυκλοφοριας'}
# {'_id': 'scheuermussweg'}
# {'_id': 'NewYork'}
# {'_id': 'JamaMasjid'}
# {'_id': 'Telugu'}
# {'_id': 'BellaCiao'}
# {'_id': 'விருதுநகர்'}
# {'_id': 'Precautions'}
# {'_id': 'News'}
# {'_id': 'Greizer'}
# {'_id': 'PARTIGIANI'}
# {'_id': 'GBL'}
# {'_id': 'flower'}
# {'_id': 'TheDevilsALie'}
# {'_id': 'jagatpapua'}
# {'_id': 'WarAgainstVirus'}
# {'_id': 'therona'}
# {'_id': 'FestadellaLiberazione'}
# {'_id': 'CoronavirusAT'}
# {'_id': 'StockMarket'}
# {'_id': 'Law'}
# {'_id': 'SONDAKIKA'}
# {'_id': 'gasmaken'}
# {'_id': 'allah'}
# {'_id': 'lectura'}
# {'_id': 'Bepositive'}
# {'_id': 'Acilia'}
# {'_id': 'Τραγούδι'}
# {'_id': 'dkgreen'}
# {'_id': 'FamilienAlleinZuHaus'}
# {'_id': 'kartu_pra_kerja'}
# {'_id': 'Twitter'}
# {'_id': 'remotelearning'}
# {'_id': 'Nachhaltigkeitstransformation'}
# {'_id': 'Selbstverwaltung'}
# {'_id': 'portraitphotography'}
# {'_id': 'Movies'}
# {'_id': 'FidelityRefundMrVictor'}
# {'_id': 'Cruz'}
# {'_id': 'Tod'}
# {'_id': 'Sahur'}
# {'_id': 'Wien'}
# {'_id': 'secularjamaat'}
# {'_id': 'caixiatemnada'}
# {'_id': 'kendaraan'}
# {'_id': 'SoCal'}
# {'_id': 'road'}
# {'_id': 'PENYEBAB'}
# {'_id': 'AskRealtorMani'}
# {'_id': 'transferhaberleri'}
# {'_id': 'UnitedAgainstCoronavirus'}
# {'_id': 'Neoliberale'}
# {'_id': 'schäuble'}
# {'_id': 'CUSB'}
# {'_id': '内閣官房'}
# {'_id': 'plants'}
# {'_id': 'immunesupport'}
# {'_id': 'DisiplinKunciHadapiCorona'}
# {'_id': 'Netzhammer'}
# {'_id': 'சென்னை'}
# {'_id': 'இளைஞரணி'}
# {'_id': 'schijtaancorona'}
# {'_id': 'oskyldig'}
# {'_id': 'Hotspot'}
# {'_id': 'spreadpositivity'}
# {'_id': 'covid19de'}
# {'_id': 'daszahnlosgamergesicht'}
# {'_id': 'Begriffe'}
# {'_id': 'Focus'}
# {'_id': 'CariBeritaditvOne'}
# {'_id': 'BuildforCovid19'}
# {'_id': 'ozibuna'}
# {'_id': 'Zwangsimpfungen'}
# {'_id': 'StayHome_Staysafe'}
# {'_id': 'ordre'}
# {'_id': 'ACUN'}
# {'_id': 'manishsingh'}
# {'_id': 'ChangeLives'}
# {'_id': 'coronavirusitalia'}
# {'_id': 'pakistan'}
# {'_id': 'Herz'}
# {'_id': 'compliance'}
# {'_id': 'Hotspots'}
# {'_id': 'PS4live'}
# {'_id': 'Sakal'}
# {'_id': 'JGPASOS'}
# {'_id': 'UniversalBasicIncome'}
# {'_id': 'Madadgaar'}
# {'_id': 'prison'}
# {'_id': 'Karliczek'}
# {'_id': 'perangsarung'}
# {'_id': 'Sonipat'}
# {'_id': 'DünyaSıtmaGünü'}
# {'_id': 'Stikstof'}
# {'_id': 'EWTN'}
# {'_id': 'NTVTelugu'}
# {'_id': 'Avigan'}
# {'_id': 'transperancy'}
# {'_id': 'contacttracing'}
# {'_id': 'gerechter'}
# {'_id': 'paintingoftheday'}
# {'_id': 'animals'}
# {'_id': 'عيد_تحرير_سيناء'}
# {'_id': 'تصميم_داخلي'}
# {'_id': 'coronanederland'}
# {'_id': 'Indore'}
# {'_id': 'Evdekalın'}
# {'_id': 'PolrestaDeliSerdang'}
# {'_id': '5वीअनुसूची'}
# {'_id': 'NoDealOnPalestine'}
# {'_id': 'abgeführt'}
# {'_id': 'NationalEmergency'}
# {'_id': 'Hindutva'}
# {'_id': 'DoubleSalaries'}
# {'_id': 'health'}
# {'_id': 'ChinaLiedPeopleDied'}
# {'_id': 'Domina'}
# {'_id': 'CoronavirusSicilia'}
# {'_id': 'GREEN'}
# {'_id': 'tindercancelados'}
# {'_id': 'andria'}
# {'_id': 'GalaxyTop20'}
# {'_id': 'WorldFightsCorona'}
# {'_id': 'braunen'}
# {'_id': 'korku'}
# {'_id': 'financialaid'}
# {'_id': 'thought'}
# {'_id': 'Kesari'}
# {'_id': 'Umwelthilfe'}
# {'_id': 'FOLLOW'}
# {'_id': 'SBI'}
# {'_id': 'Uganda'}
# {'_id': 'ReleasePoliticalPrisoners'}
# {'_id': '4daylockdown'}
# {'_id': 'ANTIFA'}
# {'_id': 'PositiveCases'}
# {'_id': 'PMUjjwalaYojna'}
# {'_id': 'publisherstory'}
# {'_id': 'LiberateIllinois'}
# {'_id': 'SocialDistancing'}
# {'_id': 'Jaihind'}
# {'_id': 'planning'}
# {'_id': 'ORF'}
# {'_id': 'Fuck'}
# {'_id': 'Story'}
# {'_id': 'rollenverteilung'}
# {'_id': 'God'}
# {'_id': 'BiharNews'}
# {'_id': 'BiharCovid19NewsUpdate'}
# {'_id': 'HALIry'}
# {'_id': 'CoronaVirus'}
# {'_id': 'StaySafeIndia'}
# {'_id': 'memelife'}
# {'_id': 'covid19Guantanamo'}
# {'_id': 'getridofwhatsapp'}
# {'_id': 'Stern'}
# {'_id': 'coronakrise'}
# {'_id': 'alcohol'}
# {'_id': 'dota2'}
# {'_id': 'Poll'}
# {'_id': 'supercomputing'}
# {'_id': 'vicc'}
# {'_id': 'hagridthebest'}
# {'_id': 'Telefonstreiche'}
# {'_id': 'KF80'}
# {'_id': 'Shops'}
# {'_id': 'KTR'}
# {'_id': 'opendeurkop'}
# {'_id': 'WalliserBote'}
# {'_id': 'pub'}
# {'_id': 'uber'}
# {'_id': 'interiordesign'}
# {'_id': 'OMG'}
# {'_id': 'marathinews'}
# {'_id': 'coronatime'}
# {'_id': 'Andhrapradesh'}
# {'_id': 'birlikteyaşayacağız'}
# {'_id': 'donaldtrump'}
# {'_id': 'DieLinke'}
# {'_id': 'starwars'}
# {'_id': 'Flowers'}
# {'_id': 'Shandong'}
# {'_id': 'stay'}
# {'_id': 'PriyankaGandhi'}
# {'_id': 'sol'}
# {'_id': 'UNTILNEXTEVENT'}
# {'_id': 'chittorgarh'}
# {'_id': 'cdU'}
# {'_id': 'Aldi'}
# {'_id': 'DMK'}
# {'_id': 'KoronaBisaDisembuhkan'}
# {'_id': 'macizle'}
# {'_id': 'balsena'}
# {'_id': 'Nadiaali'}
# {'_id': 'banten'}
# {'_id': 'Umwelt'}
# {'_id': 'カード'}
# {'_id': 'worldmusic'}
# {'_id': 'YadVashem'}
# {'_id': 'Uni'}
# {'_id': 'ريتويت'}
# {'_id': 'WBCOVID19Tracker'}
# {'_id': 'pune'}
# {'_id': 'online'}
# {'_id': 'kizilay'}
# {'_id': 'mutluaksamlar'}
# {'_id': 'MijnSerie'}
# {'_id': 'ZeeMusicCompany'}
# {'_id': 'begrotingstekort'}
# {'_id': 'NoToWTE'}
# {'_id': 'zugezogne'}
# {'_id': 'neuland'}
# {'_id': 'codcimahi'}
# {'_id': 'strongwoman'}
# {'_id': 'PowerPoint'}
# {'_id': 'इटली'}
# {'_id': 'CENTRI'}
# {'_id': 'الزم_بيتك_حمايه_لك_ولمجتمعك'}
# {'_id': 'DisinfectantDonnie'}
# {'_id': 'CoronaPositiveCaseNathdwaraRajsamand'}
# {'_id': 'Digitalausschuss'}
# {'_id': 'gatewaytojannah_'}
# {'_id': 'noAfD'}
# {'_id': 'LIVE'}
# {'_id': 'BleachGate'}
# {'_id': 'RubikaLiyaquat'}
# {'_id': 'ಕೊರೊನಾಲಜಿ'}
# {'_id': 'tomhanks'}
# {'_id': 'IederVoorZich'}
# {'_id': '小池都知事'}
# {'_id': 'woningcorporaties'}
# {'_id': 'mamtabanerjee'}
# {'_id': 'LOCKDOWN'}
# {'_id': 'Legend'}
# {'_id': 'Edge'}
# {'_id': '슙디에게물어봐'}
# {'_id': 'coronaprevention'}
# {'_id': 'missionkaali'}
# {'_id': 'ChefboyKola'}
# {'_id': 'kleurplaten'}
# {'_id': 'AfD'}
# {'_id': 'Einzelhandel'}
# {'_id': 'parbhanikar'}
# {'_id': 'heinsbergprotokoll'}
# {'_id': 'SARSCoV2'}
# {'_id': 'Quarks'}
# {'_id': 'sokakhayvanları'}
# {'_id': 'மும்பை'}
# {'_id': 'ラバ'}
# {'_id': 'TheGreatAwaking'}
# {'_id': 'Hygienedemo'}
# {'_id': 'Russian'}
# {'_id': 'GreenDeal'}
# {'_id': 'çaylıca'}
# {'_id': 'أوروبا'}
# {'_id': 'catholicband'}
# {'_id': 'Minetest'}
# {'_id': 'airIndia'}
# {'_id': 'Moral'}
# {'_id': 'ArrestWIRepublicans'}
# {'_id': 'ndiyo'}
# {'_id': 'uefa'}
# {'_id': 'batanghari'}
# {'_id': 'survivorekstra'}
# {'_id': 'Unfit'}
# {'_id': 'Allemagne'}
# {'_id': 'FREE'}
# {'_id': 'Rechtsstaat'}
# {'_id': 'BaWü'}
# {'_id': 'sunrise'}
# {'_id': 'Klimadialog'}
# {'_id': 'Germany'}
# {'_id': 'Artensterben'}
# {'_id': 'kyudararahihaidharavi'}
# {'_id': 'leadership'}
# {'_id': 'HealthyAtHome'}
# {'_id': 'alberheijn'}
# {'_id': 'tollywood'}
# {'_id': 'ramadhan'}
# {'_id': 'Nierstichting'}
# {'_id': 'Gurgaon'}
# {'_id': 'NovelCoronaViruse'}
# {'_id': 'tarsus'}
# {'_id': 'glassart'}
# {'_id': 'drvivekbindra'}
# {'_id': '茅野市'}
# {'_id': 'MileleWeekendParty'}
# {'_id': 'problem2'}
# {'_id': 'Abstandsregeln'}
# {'_id': 'nutritionist'}
# {'_id': 'qualitytime'}
# {'_id': 'women'}
# {'_id': 'Sueddeutsche'}
# {'_id': 'breakfastofchampions'}
# {'_id': 'schulöffnungen'}
# {'_id': 'workfromhome'}
# {'_id': 'SupplyChain'}
# {'_id': 'philiasolutions'}
# {'_id': 'Schweiz'}
# {'_id': 'garjanai'}
# {'_id': 'TrumpIsAnIdiot'}
# {'_id': 'bihar'}
# {'_id': 'ज्ञानी'}
# {'_id': 'CDU'}
# {'_id': 'Muslims'}
# {'_id': 'ExpoTANGERANG'}
# {'_id': 'Robotics'}
# {'_id': 'latepost'}
# {'_id': 'CITWEndingTheChase'}
# {'_id': 'साधुओं_के_हत्यारों_को_बिरयानी'}
# {'_id': 'Refugees'}
# {'_id': 'Lockerungsübungen'}
# {'_id': 'Urantransport'}
# {'_id': 'SahurVakti'}
# {'_id': 'WuFlu'}
# {'_id': 'محايل_عسير'}
# {'_id': 'ArtificialIntelligence'}
# {'_id': 'Coronacrisis'}
# {'_id': 'RheinSieg'}
# {'_id': 'IndiaLockdown'}
# {'_id': 'olvg'}
# {'_id': 'tbt'}
# {'_id': 'bhopal'}
# {'_id': 'lontanimavicini'}
# {'_id': 'காலை'}
# {'_id': 'news'}
# {'_id': 'وزير_الصحة'}
# {'_id': 'Humanitarian'}
# {'_id': 'RhomaIrama'}
# {'_id': 'FitzgeraldOwnsEveryWIDeath'}
# {'_id': 'Alemania'}
# {'_id': 'WeAreTheNewsNow'}
# {'_id': 'terapi'}
# {'_id': 'whatdayisit'}
# {'_id': 'Gottem'}
# {'_id': 'MigrantLabourers'}
# {'_id': 'versammlungsbehörde'}
# {'_id': 'sadhguruquotes'}
# {'_id': 'Augstein'}
# {'_id': 'KabarGembira'}
# {'_id': 'brasil'}
# {'_id': 'saveindia'}
# {'_id': 'TamilNadu'}
# {'_id': 'gayrubbersox'}
# {'_id': 'alpha'}
# {'_id': 'trono'}
# {'_id': 'Saveus'}
# {'_id': 'coronaindia'}
# {'_id': 'nkri'}
# {'_id': 'mattarella'}
# {'_id': 'NewsEpicentre'}
# {'_id': 'અમદાવાદ'}
# {'_id': 'Senegal'}
# {'_id': 'flattenthecurve'}
# {'_id': 'CoronaVirusCrisisFund'}
# {'_id': 'Lupin'}
# {'_id': 'gibberish'}
# {'_id': 'endthelockdownnow'}
# {'_id': 'コロナが終わったらしたいこと'}
# {'_id': 'Qingdao'}
# {'_id': 'niforganik'}
# {'_id': 'asiaeconomy'}
# {'_id': 'lawofattraction'}
# {'_id': 'BersamakitaBisa'}
# {'_id': 'Lehrer'}
# {'_id': 'CastingCrushesCorona'}
# {'_id': 'DEESA'}
# {'_id': 'ugent'}
# {'_id': 'Pflegenotstand'}
# {'_id': 'uzay'}
# {'_id': 'ODP'}
# {'_id': 'GUJARAT'}
# {'_id': 'bandarra'}
# {'_id': 'gocoronago'}
# {'_id': 'Anhänger'}
# {'_id': 'CoronaVirus_de'}
# {'_id': 'Begrotingstekort'}
# {'_id': 'MIAKA56'}
# {'_id': 'Trumpadas'}
# {'_id': 'Aaj_tak'}
# {'_id': 'Nederland'}
# {'_id': 'BiggerOnTheInside'}
# {'_id': 'Citytimestv'}
# {'_id': 'hanumanjanmotsav'}
# {'_id': 'Koronavirüs'}
# {'_id': 'भारत'}
# {'_id': 'AndrewCuomo'}
# {'_id': 'Vegan'}
# {'_id': 'AfDgehoertnichtzuDeutschland'}
# {'_id': 'الطايف_الان'}
# {'_id': 'the'}
# {'_id': 'spray'}
# {'_id': 'CoronaInazuilika'}
# {'_id': 'PowerSportz'}
# {'_id': 'kumparanNews'}
# {'_id': 'globalhealth'}
# {'_id': 'StayathHome'}
# {'_id': 'Torontosafe'}
# {'_id': 'pegasus'}
# {'_id': 'Revival'}
# {'_id': 'creative'}
# {'_id': 'pasta'}
# {'_id': 'Politieagent'}
# {'_id': 'mondodelpallone'}
# {'_id': 'bluesky'}
# {'_id': 'कोरोना_स्थिति'}
# {'_id': 'canadanews'}
# {'_id': 'education'}
# {'_id': 'AMMK'}
# {'_id': 'Klimaschutz'}
# {'_id': 'CDA'}
# {'_id': 'isolamento'}
# {'_id': 'momfail'}
# {'_id': 'NP'}
# {'_id': 'stimmung'}
# {'_id': 'Ferguswalsh'}
# {'_id': 'FromBerlinWithLove'}
# {'_id': 'Montesquieu'}
# {'_id': 'LokSabha'}
# {'_id': 'EstouFechadoComBolsonaro'}
# {'_id': 'MassSurveillance'}
# {'_id': 'Djkhathu'}
# {'_id': 'Vertrauen'}
# {'_id': 'allergi'}
# {'_id': '75j'}
# {'_id': 'Oberbayern'}
# {'_id': 'Barbie'}
# {'_id': 'Clorox'}
# {'_id': 'ASAPNatinTo'}
# {'_id': 'Felicitated'}
# {'_id': 'traveltips'}
# {'_id': 'Safelives'}
# {'_id': 'CoronaInOdisha'}
# {'_id': 'PresidentTrump'}
# {'_id': 'sakalnews'}
# {'_id': 'US'}
# {'_id': 'bbc'}
# {'_id': 'berita'}
# {'_id': 'COVID19deutschland'}
# {'_id': 'BleachPlease'}
# {'_id': 'interesting'}
# {'_id': 'Maara'}
# {'_id': 'RuhrUniRemote'}
# {'_id': 'timbeta'}
# {'_id': 'demonstrationen'}
# {'_id': 'Domuz'}
# {'_id': 'dindasdindom'}
# {'_id': 'Online'}
# {'_id': 'stayathomechallenge'}
# {'_id': 'deportation'}
# {'_id': 'FoodDemands'}
# {'_id': 'Metooindia'}
# {'_id': 'WirVsVirus'}
# {'_id': 'Aslında'}
# {'_id': 'Hummels'}
# {'_id': 'CintaLaura'}
# {'_id': 'kpopmemes'}
# {'_id': 'TrumpPressConf'}
# {'_id': 'manmohansingh'}
# {'_id': 'Militär'}
# {'_id': 'varusteleka'}
# {'_id': 'coronavid19'}
# {'_id': 'Mitte'}
# {'_id': 'WestBengal'}
# {'_id': 'professionalizeMICROBIOLOGY'}
# {'_id': 'Tote'}
# {'_id': 'walsallfc'}
# {'_id': '日本人偽装保守'}
# {'_id': 'MustafaKocak'}
# {'_id': 'staysafe'}
# {'_id': 'UWENDE_LIPWELA_________'}
# {'_id': 'Covid19Out'}
# {'_id': 'WB'}
# {'_id': 'RedZone'}
# {'_id': 'PMOfIndia'}
# {'_id': 'Attenzione'}
# {'_id': 'kita'}
# {'_id': 'aiimsraipur'}
# {'_id': 'cancelled'}
# {'_id': 'sociale'}
# {'_id': 'Pleitewelle'}
# {'_id': 'Superiore'}
# {'_id': 'niños'}
# {'_id': 'बिजली_आउटसोर्स_कर्मवीर'}
# {'_id': 'bucharest'}
# {'_id': 'StateOfTheNation'}
# {'_id': 'maatregelen'}
# {'_id': 'お初天神'}
# {'_id': 'شهر_رمضان_المبارك'}
# {'_id': 'Live'}
# {'_id': 'Stadtklimainitiativen'}
# {'_id': 'veille'}
# {'_id': 'sprachlos'}
# {'_id': 'Zusammen'}
# {'_id': 'TSR'}
# {'_id': 'AmtsblattFreiburg'}
# {'_id': 'iyiakşamlar'}
# {'_id': 'Bankers'}
# {'_id': 'फॉलोवर्स'}
# {'_id': 'lockDown'}
# {'_id': 'Ireland'}
# {'_id': 'Filipijnseten'}
# {'_id': 'coronalockdown'}
# {'_id': 'PolizeiSaarland'}
# {'_id': 'myinterior'}
# {'_id': 'JabalPur'}
# {'_id': 'Einkaufswage'}
# {'_id': 'groceryshopping'}
# {'_id': 'Gesundheit'}
# {'_id': 'promo'}
# {'_id': 'snapchat'}
# {'_id': 'IzkiaPopapo'}
# {'_id': 'weareback'}
# {'_id': 'ஈரோடு'}
# {'_id': 'CórdobaEsp'}
# {'_id': 'FabreadsDigest'}
# {'_id': 'jtrun'}
# {'_id': 'automatic'}
# {'_id': 'PresidenteBolsonaro'}
# {'_id': 'Bhopal'}
# {'_id': 'zwangerschap'}
# {'_id': 'spamfrasesdereggaeton'}
# {'_id': 'RobertKoch'}
# {'_id': 'GouravVallabh'}
# {'_id': 'Coronavirustruth'}
# {'_id': 'Pandemic'}
# {'_id': 'NeverAgainToLP'}
# {'_id': 'np'}
# {'_id': '翻墙'}
# {'_id': 'plasmatherapy'}
# {'_id': 'Queen'}
# {'_id': 'alagartemplefestival'}
# {'_id': 'ziekenhuizen'}
# {'_id': 'fifa'}
# {'_id': 'Algérie'}
# {'_id': 'Virologe'}
# {'_id': 'wirsindbernau'}
# {'_id': 'Dr_Imran_Saeed'}
# {'_id': 'neleroluyorhayatta'}
# {'_id': 'France'}
# {'_id': 'PMI'}
# {'_id': '密です'}
# {'_id': 'buena'}
# {'_id': 'AkshayKumar'}
# {'_id': 'Scrap498A'}
# {'_id': 'Democrats'}
# {'_id': 'संतरामपालजी_का_सत्संग_सुनेंThe'}
# {'_id': 'CultureetSociété'}
# {'_id': 'KOT'}
# {'_id': 'Klimafolgenforschung'}
# {'_id': 'coronaupdatesindia'}
# {'_id': 'ZuhauseBleiben'}
# {'_id': 'sigara'}
# {'_id': 'ContainmentAreas'}
# {'_id': 'tribunaal'}
# {'_id': 'சென்னையில்'}
# {'_id': 'Plasmatherapytrials'}
# {'_id': 'Recruiting'}
# {'_id': 'RegnoUnito'}
# {'_id': 'குஜராத்'}
# {'_id': 'owner'}
# {'_id': 'عسير'}
# {'_id': 'ديكورات_حديثة'}
# {'_id': 'enfants'}
# {'_id': 'Dreyer'}
# {'_id': 'Cases'}
# {'_id': 'Wittlich'}
# {'_id': 'games'}
# {'_id': 'She'}
# {'_id': 'Socialdistancing'}
# {'_id': 'Belgie'}
# {'_id': 'Iksharma'}
# {'_id': 'FFP3'}
# {'_id': 'ETVBharatTamilnadu'}
# {'_id': 'homelab'}
# {'_id': 'festadellaliberazione'}
# {'_id': 'Cumartesi'}
# {'_id': 'China'}
# {'_id': 'TBT'}
# {'_id': 'NieMehrCDU'}
# {'_id': 'RSS'}
# {'_id': 'gamedev'}
# {'_id': 'AnsorBelaNegeri'}
# {'_id': 'vcstrusted'}
# {'_id': 'NiceToSeeYou'}
# {'_id': 'ecfra20'}
# {'_id': 'break'}
# {'_id': 'Michelle_Bachelet'}
# {'_id': 'RSP'}
# {'_id': 'gabut'}
# {'_id': 'Umweltschutz'}
# {'_id': 'ludojokes'}
# {'_id': 'ElPeorPresidenteDeLaHistoria'}
# {'_id': 'readyVCS'}
# {'_id': 'Let'}
# {'_id': 'neuelinkemehrheiten'}
# {'_id': 'EastTurkistan'}
# {'_id': 'ÖzgürDeğilCHPMedyası'}
# {'_id': 'masks'}
# {'_id': 'rbigovernor'}
# {'_id': 'セルフ体験に'}
# {'_id': 'FauciDeepState'}
# {'_id': 'LaxmmiBomb'}
# {'_id': 'mandelorian'}
# {'_id': 'Madurai'}
# {'_id': 'म'}
# {'_id': 'DilSeThankYou'}
# {'_id': 'Campain'}
# {'_id': 'Nygard'}
# {'_id': 'Beer'}
# {'_id': 'Shanghai'}
# {'_id': 'INTERCESSION'}
# {'_id': 'JammuKashmir'}
# {'_id': 'JagaJarak'}
# {'_id': 'Lockdown2'}
# {'_id': 'CoronaWillEndSoon'}
# {'_id': 'Fortnite'}
# {'_id': 'श्रीहनुमान_जयंती'}
# {'_id': 'bahnhof'}
# {'_id': 'macho'}
# {'_id': 'Staysafe'}
# {'_id': 'YapımcıEşkiyaCanan'}
# {'_id': 'StayHome'}
# {'_id': 'support'}
# {'_id': 'Capelle'}
# {'_id': 'amersfoort'}
# {'_id': 'purwokerto'}
# {'_id': 'donaukanal'}
# {'_id': 'baroda'}
# {'_id': 'brasileiros'}
# {'_id': 'Neukölln'}
# {'_id': 'malamminggu'}
# {'_id': 'Fightback'}
# {'_id': 'emptyhomes'}
# {'_id': 'clickthompsonphotography'}
# {'_id': 'اسبانيا'}
# {'_id': 'Superheroes'}
# {'_id': 'diyet'}
# {'_id': 'tisshyderabad'}
# {'_id': 'Regeln'}
# {'_id': 'Meme'}
# {'_id': 'WNI'}
# {'_id': 'RahulGandhi'}
# {'_id': 'kemp'}
# {'_id': 'Sabret'}
# {'_id': 'ArminWolf'}
# {'_id': 'Afghanistan'}
# {'_id': 'warning'}
# {'_id': 'jungkook'}
# {'_id': 'Maroc'}
# {'_id': 'Salute2CoronaWarriors'}
# {'_id': 'دبي'}
# {'_id': 'NOBORDER'}
# {'_id': 'Berpuasa'}
# {'_id': 'CriseCovid19'}
# {'_id': 'TNFightsCorona'}
# {'_id': 'JeetoPakistanLeague'}
# {'_id': 'lagucorona'}
# {'_id': 'Vorbilder'}
# {'_id': 'werkgezocht'}
# {'_id': 'Qanon'}
# {'_id': 'StayPositive_StaySafe'}
# {'_id': 'MamataBanerjee'}
# {'_id': 'mumbaipolice'}
# {'_id': 'Werbung'}
# {'_id': '3dmodel'}
# {'_id': 'Mandic'}
# {'_id': 'blackroommedia'}
# {'_id': 'Crisis'}
# {'_id': 'gebermis'}
# {'_id': 'BangsatBangsa'}
# {'_id': 'daspolitikteil'}
# {'_id': 'Japan'}
# {'_id': 'Abortionpills'}
# {'_id': 'CSD'}
# {'_id': 'tea'}
# {'_id': 'アマビエチャレンジ'}
# {'_id': 'mybmc'}
# {'_id': 'EarthDay2020'}
# {'_id': 'Nss_unit_gurugram'}
# {'_id': 'igers'}
# {'_id': 'AMJoy'}
# {'_id': 'somaiçinacilönlem'}
# {'_id': 'AkhyarNasution'}
# {'_id': 'Gamecetera'}
# {'_id': 'hayatevesığar'}
# {'_id': 'misinformation'}
# {'_id': 'Morons'}
# {'_id': 'relieffund'}
# {'_id': 'Schutzmaske'}
# {'_id': 'RobertKochInstitut'}
# {'_id': 'SimpleIdeas'}
# {'_id': 'PRESIDENTE'}
# {'_id': 'LetsChangeBihar'}
# {'_id': 'irelandvscovid'}
# {'_id': 'FaseTres'}
# {'_id': 'België'}
# {'_id': 'quranquotes'}
# {'_id': 'öffentlich'}
# {'_id': 'Polizisten'}
# {'_id': 'Korean'}
# {'_id': '2020WasFunUntilpresident'}
# {'_id': 'AI'}
# {'_id': 'Laschet'}
# {'_id': 'HappyBirthdaySachin'}
# {'_id': 'GhostWar'}
# {'_id': 'bireyakademikampüsü'}
# {'_id': 'Frankfurt'}
# {'_id': 'WaPo'}
# {'_id': 'klopapier'}
# {'_id': 'pronhub'}
# {'_id': 'DontDrinkBleach'}
# {'_id': 'CoronaHeroes'}
# {'_id': 'Anticoronaforce'}
# {'_id': 'Chaoten'}
# {'_id': 'BharatSamachar'}
# {'_id': 'pandemicCovid19'}
# {'_id': 'CoronaKrise'}
# {'_id': 'karnal'}
# {'_id': 'GiveDAtoGovtEmployee'}
# {'_id': 'OperationCovid19'}
# {'_id': 'nurdieSGE'}
# {'_id': 'BankersOnDuty'}
# {'_id': '25aprile2020'}
# {'_id': 'demonitor'}
# {'_id': 'Sachsen'}
# {'_id': 'ديكور_خشبي'}
# {'_id': 'لبنان'}
# {'_id': 'bacotsantuy'}
# {'_id': 'freelance'}
# {'_id': 'Sambia'}
# {'_id': 'MMOW'}
# {'_id': 'cherryblossom'}
# {'_id': 'animalcruelty'}
# {'_id': 'StayHomeIndia'}
# {'_id': 'CoronaVirusKhandwa'}
# {'_id': 'imamoğlu'}
# {'_id': 'myphoto'}
# {'_id': 'StayA'}
# {'_id': 'trumpfun'}
# {'_id': 'FightBreakIndiaGang'}
# {'_id': 'stress'}
# {'_id': 'ideas'}
# {'_id': 'uts'}
# {'_id': 'humor'}
# {'_id': 'Nazi'}
# {'_id': 'dirumahaja'}
# {'_id': 'Ground'}
# {'_id': 'कोरोना_मुबारक_मित्रों'}
# {'_id': 'hamidmir'}
# {'_id': 'Hashtag'}
# {'_id': 'yash'}
# {'_id': 'Anuna'}
# {'_id': 'takemehome'}
# {'_id': 'dangerous'}
# {'_id': 'Stadtverkehr'}
# {'_id': 'Balsena'}
# {'_id': 'BillGates'}
# {'_id': 'CoronaVirüs'}
# {'_id': 'kathniel'}
# {'_id': 'Virologen'}
# {'_id': '引越し'}
# {'_id': 'tiktokindia'}
# {'_id': 'कोराेना_वायरस'}
# {'_id': 'thuisblijven'}
# {'_id': 'MogoduMonday'}
# {'_id': 'noco_art'}
# {'_id': 'GeopoliticsPandemia'}
# {'_id': 'إسبانيا'}
# {'_id': 'Mansplaining'}
# {'_id': 'Covid19'}
# {'_id': 'coronaviruscovid19'}
# {'_id': 'कोलेजियम_सिस्टम_नही_चलेगा'}
# {'_id': 'InfectiousDiseases'}
# {'_id': 'Widerstand'}
# {'_id': 'eKhabri'}
# {'_id': '256_की_मौत'}
# {'_id': 'uttarpradesh'}
# {'_id': 'corona_ist_ein_Hurensohn'}
# {'_id': 'jaideshpartyonline'}
# {'_id': 'CoronaUpdateBihar'}
# {'_id': 'EvdeHayatVar'}
# {'_id': 'QueenArcane'}
# {'_id': 'YOUNGMONEYRADIO'}
# {'_id': 'coronasweden'}
# {'_id': 'LifebuoyKarona'}
# {'_id': 'ClimateCrisis'}
# {'_id': 'ગુજરાતનેપાકિસ્તાનબનતુઅટકાવો'}
# {'_id': 'creator'}
# {'_id': 'NoToHalalStampOnMyFood'}
# {'_id': 'SendUsBackHome'}
# {'_id': 'ActofKindness'}
# {'_id': 'Nepalese'}
# {'_id': 'temples'}
# {'_id': 'Lockerung'}
# {'_id': 'Vermögensabgabe'}
# {'_id': 'PostCovid19'}
# {'_id': 'threethings'}
# {'_id': 'Sabadou'}
# {'_id': 'Handelskammer'}
# {'_id': 'BalconyStories'}
# {'_id': 'coronatamilnadu'}
# {'_id': 'ChinaLiedAndPeopleDied'}
# {'_id': 'Capital'}
# {'_id': 'Ciamis'}
# {'_id': 'Tangerhütte'}
# {'_id': 'mayor'}
# {'_id': 'accra'}
# {'_id': 'Freiburg'}
# {'_id': 'BankersPower'}
# {'_id': 'Muezzinruf'}
# {'_id': 'TBMM100Yaşında'}
# {'_id': 'onelove'}
# {'_id': 'Chinese'}
# {'_id': 'coronacouchconcert'}
# {'_id': 'रामनवमी'}
# {'_id': 'Grofers'}
# {'_id': 'intense'}
# {'_id': 'healthy'}
# {'_id': 'cimshospital'}
# {'_id': 'NAH'}
# {'_id': 'JustAsking'}
# {'_id': 'maskon'}
# {'_id': 'coronachallenge'}
# {'_id': 'Oflagos'}
# {'_id': 'lines'}
# {'_id': 'Event201'}
# {'_id': 'libros'}
# {'_id': 'horticulteurs'}
# {'_id': 'healthcare'}
# {'_id': 'Zoo'}
# {'_id': 'GoodVibes'}
# {'_id': '8kun'}
# {'_id': 'Odalarevu'}
# {'_id': 'mantelzorg'}
# {'_id': 'FechadoComBolsonaroAte2026'}
# {'_id': 'Grundeinkommen'}
# {'_id': 'shaming'}
# {'_id': 'Duesseldorf'}
# {'_id': 'வீட்டில்இரு'}
# {'_id': 'bignews9'}
# {'_id': 'चमगादड़'}
# {'_id': 'climatechange'}
# {'_id': 'kritik'}
# {'_id': 'doden'}
# {'_id': 'みっし～'}
# {'_id': 'redzone'}
# {'_id': 'Atemschutzmasken'}
# {'_id': 'Favipiravir'}
# {'_id': 'London'}
# {'_id': 'jikingedhidiyacorona'}
# {'_id': 'LockdownInUP'}
# {'_id': 'Disinfektan'}
# {'_id': 'Rusya'}
# {'_id': 'जय_हिन्द'}
# {'_id': 'COVID19_de'}
# {'_id': 'problem4'}
# {'_id': 'Gleichheit'}
# {'_id': 'vechtscheiding'}
# {'_id': 'legalize'}
# {'_id': 'survivor2020'}
# {'_id': 'StayHomeStaySafe'}
# {'_id': 'USAVirus'}
# {'_id': 'KırmızıKoltuğaHayır'}
# {'_id': 'Telangana'}
# {'_id': 'hoezo'}
# {'_id': 'AnzacDay'}
# {'_id': 'Demonstrations'}
# {'_id': 'HAYS'}
# {'_id': 'TrumpDisinfectant'}
# {'_id': 'போட்டோ'}
# {'_id': 'aiims'}
# {'_id': 'weareinthistogether'}
# {'_id': 'cobot'}
# {'_id': 'كلنامسؤول'}
# {'_id': 'coffeetime'}
# {'_id': 'Covid_19'}
# {'_id': 'Canada'}
# {'_id': 'Pandemia'}
# {'_id': 'din'}
# {'_id': 'CoronaEltern'}
# {'_id': 'Utrecht'}
# {'_id': 'verslappen'}
# {'_id': 'andriesi'}
# {'_id': 'Am'}
# {'_id': 'ConfinementJour40'}
# {'_id': 'AniesBaswedan'}
# {'_id': 'ganja'}
# {'_id': 'Jinnah'}
# {'_id': 'JaiHind'}
# {'_id': 'Self'}
# {'_id': 'icecream'}
# {'_id': 'CoronaStopKaroNa'}
# {'_id': 'MİLLETİMİZE'}
# {'_id': 'lockdown'}
# {'_id': 'Stayathome'}
# {'_id': 'extendedlockdown'}
# {'_id': 'Healthy'}
# {'_id': 'Comedy'}
# {'_id': '緊急事態宣言'}
# {'_id': 'nutricion'}
# {'_id': 'COVID19PH'}
# {'_id': 'covidcartoonoftheday'}
# {'_id': 'Patna'}
# {'_id': 'HCPNetwork'}
# {'_id': 'home_quarantine'}
# {'_id': 'laffehandhaving'}
# {'_id': 'Jharkhand'}
# {'_id': 'Mahabhart'}
# {'_id': 'ligabbvamx'}
# {'_id': 'drag'}
# {'_id': 'fanzin'}
# {'_id': 'maskenpflicht'}
# {'_id': 'ALRATV'}
# {'_id': 'ICantBelieveItsNotButter'}
# {'_id': 'ikea'}
# {'_id': 'Ladycat'}
# {'_id': 'BLEACH2020'}
# {'_id': 'KAG2020'}
# {'_id': 'Hinduphobia_in_Jharkhand'}
# {'_id': 'rubia'}
# {'_id': 'FridayFollies'}
# {'_id': 'Krieg'}
# {'_id': 'vray'}
# {'_id': 'Sylt'}
# {'_id': 'Deutschland'}
# {'_id': 'tablighijamaatvirus'}
# {'_id': 'Senator'}
# {'_id': 'OpenMemphisNow'}
# {'_id': 'SrikantheGowda'}
# {'_id': 'bbnaijaupdate'}
# {'_id': 'spreadshirt'}
# {'_id': 'günleri'}
# {'_id': 'Frankreich'}
# {'_id': 'byViviennerreich'}
# {'_id': 'TOP'}
# {'_id': 'burger'}
# {'_id': 'BigBreaking'}
# {'_id': 'kayseri'}
# {'_id': 'COVIDIOT'}
# {'_id': 'Tlaxcala'}
# {'_id': 'followtrick'}
# {'_id': 'HarHarMahadev'}
# {'_id': 'brasileiro'}
# {'_id': 'Mbbsinternuniformstipend'}
# {'_id': 'VS'}
# {'_id': 'Covid19turkey'}
# {'_id': 'TheGreatAwakening'}
# {'_id': 'RegulariseSSEsAEOs'}
# {'_id': 'sidnaaz'}
# {'_id': 'creativequarantine'}
# {'_id': 'Humble'}
# {'_id': 'ING'}
# {'_id': 'Cerveau'}
# {'_id': 'كوفيد١٩'}
# {'_id': 'canlimacizle'}
# {'_id': 'parody'}
# {'_id': 'convention'}
# {'_id': 'Toronto'}
# {'_id': 'restart'}
# {'_id': 'JaipurToday'}
# {'_id': 'infocorona'}
# {'_id': 'UGM'}
# {'_id': 'Pfarrerstochter'}
# {'_id': 'GloboLixo'}
# {'_id': 'Kekule'}
# {'_id': 'recovered'}
# {'_id': 'CoronavirusProject'}
# {'_id': 'MaskerUntukSemua'}
# {'_id': 'Halal'}
# {'_id': 'Coronavirus'}
# {'_id': 'MARVEL'}
# {'_id': '27deabril2020'}
# {'_id': 'healthychoices'}
# {'_id': 'covid19Nederland'}
# {'_id': 'Podcast'}
# {'_id': 'TwitterFoodBank'}
# {'_id': 'coronaindonesia'}
# {'_id': 'Nørderi'}
# {'_id': 'venom'}
# {'_id': 'Master'}
# {'_id': 'CCP'}
# {'_id': 'UN'}
# {'_id': 'southafrica'}
# {'_id': 'OPENAMERICANOW'}
# {'_id': '81milyongb'}
# {'_id': 'artikel'}
# {'_id': 'ongeschikt'}
# {'_id': 'kcpengineers'}
# {'_id': 'ilovemusic'}
# {'_id': 'keralapolice'}
# {'_id': 'FragenüberFragen'}
# {'_id': 'torontofoodie'}
# {'_id': 'newstarterfurlough'}
# {'_id': 'Madhyapradesh'}
# {'_id': 'Kothagudem'}
# {'_id': 'Odisha'}
# {'_id': 'wwe'}
# {'_id': 'AirDisinfectant'}
# {'_id': 'PRMPeduliKorbanCovid19'}
# {'_id': 'HealthModel'}
# {'_id': 'FechadocomBolsonaro'}
# {'_id': 'sendUshomeback'}
# {'_id': 'MaduraiFightsCorona'}
# {'_id': 'ontsmettingsmiddel'}
# {'_id': 'スウェーデン'}
# {'_id': 'gujarat'}
# {'_id': 'NarendraModi'}
# {'_id': 'CANLI'}
# {'_id': 'KIMSBhubaneswar'}
# {'_id': 'jaideshandhra'}
# {'_id': 'welkombijjezelf'}
# {'_id': 'fanatikcomtr'}
# {'_id': 'CoronaPune'}
# {'_id': 'Hmc'}
# {'_id': 'SALMANKHAN'}
# {'_id': 'Sharona'}
# {'_id': 'freedom'}
# {'_id': 'Bürgerbeteiligung'}
# {'_id': 'WorldMalariaDay'}
# {'_id': 'SchleswigHolstein'}
# {'_id': 'RamazanDeyince'}
# {'_id': 'pidealmayadiyeçıkıp'}
# {'_id': 'infecties'}
# {'_id': 'salgın'}
# {'_id': 'AvantGardePremier'}
# {'_id': 'ElsaNoguera'}
# {'_id': 'Tagesthemen'}
# {'_id': 'Geisterflughäfen'}
# {'_id': 'CoronavirusOutbreak'}
# {'_id': 'कोलेजियम_सिस्टम_नहीं_चलेगा'}
# {'_id': '白木'}
# {'_id': 'cmyogi'}
# {'_id': 'year2020'}
# {'_id': 'யாழ்_பல்கலைக்கழக'}
# {'_id': 'LockDown'}
# {'_id': 'மதவெறிபிடித்து'}
# {'_id': 'ホットヨガスタジオlava'}
# {'_id': 'AltaredellaPatria'}
# {'_id': 'stayathome'}
# {'_id': 'samedi'}
# {'_id': 'दिल्ली'}
# {'_id': 'BailoutThePlanet'}
# {'_id': 'droogte'}
# {'_id': 'EL'}
# {'_id': 'Ramelow'}
# {'_id': 'Aachen'}
# {'_id': 'DemocratsAreADisgrace'}
# {'_id': 'ChinaStory'}
# {'_id': '氷上テキーラーズ'}
# {'_id': 'dolor'}
# {'_id': 'hypnose'}
# {'_id': 'Thappad'}
# {'_id': 'Auto'}
# {'_id': 'MadhyaPradesh'}
# {'_id': 'gelombang_kedua'}
# {'_id': '加油'}
# {'_id': 'left'}
# {'_id': 'sonko'}
# {'_id': 'SpanishFlu'}
# {'_id': '新型コロナ'}
# {'_id': 'nurgülyeşilçay'}
# {'_id': 'CashAppFriday'}
# {'_id': 'funny'}
# {'_id': 'Macht'}
# {'_id': 'ನಿಷ್ಠುರ'}
# {'_id': 'ghana'}
# {'_id': 'AşkSevgidenBeter'}
# {'_id': 'loveyouall'}
# {'_id': 'CovidWarriors'}
# {'_id': 'HelpingHands'}
# {'_id': 'pictureoftheday'}
# {'_id': 'SelfCongratulatoryBluster'}
# {'_id': 'SaintMSG'}
# {'_id': 'TevfikÖzlü'}
# {'_id': 'ChileVotaDignidad'}
# {'_id': 'अन्धभक्त'}
# {'_id': 'Madagascar'}
# {'_id': 'bulanramadhan'}
# {'_id': 'salons'}
# {'_id': 'MoroTraidor'}
# {'_id': 'Austria'}
# {'_id': 'WWT'}
# {'_id': 'Ballermann'}
# {'_id': 'sadka'}
# {'_id': 'コロナウイルス美容室経営借入チェック表'}
# {'_id': 'bleekmiddel'}
# {'_id': 'sanat'}
# {'_id': 'chattisgarh'}
# {'_id': 'معا_في_رمضان'}
# {'_id': 'coro'}
# {'_id': 'sosyoloji'}
# {'_id': 'Hinduphobia'}
# {'_id': 'Angststoerungen'}
# {'_id': 'BPBDKudus'}
# {'_id': 'anime'}
# {'_id': 'Viren'}
# {'_id': 'Sarkasmustweet'}
# {'_id': 'PopupBikelane'}
# {'_id': 'झेप'}
# {'_id': 'nutrition'}
# {'_id': 'lockdownmemes'}
# {'_id': 'Muslim'}
# {'_id': 'attack'}
# {'_id': 'viral'}
# {'_id': 'CurfewinKenya'}
# {'_id': 'Shabbat'}
# {'_id': 'Erlangen'}
# {'_id': 'belalıbaldız'}
# {'_id': 'leven'}
# {'_id': 'coronaravirus'}
# {'_id': 'Royapuram'}
# {'_id': 'pappaserissipit'}
# {'_id': 'denverfashion'}
# {'_id': 'Feyenoord'}
# {'_id': 'quotes'}
# {'_id': 'DiRumahAja'}
# {'_id': 'Great'}
# {'_id': 'woman'}
# {'_id': 'abhishekbanerjee'}
# {'_id': 'काफिर_झटका_माँगेगा'}
# {'_id': 'Pimms'}
# {'_id': 'religion'}
# {'_id': 'ikim'}
# {'_id': 'Saarland'}
# {'_id': 'Celebrities'}
# {'_id': 'kano'}
# {'_id': 'MaisUmaNaoTemJeito'}
# {'_id': 'Fearnotcorona'}
# {'_id': 'ReopenAmericaNow'}
# {'_id': 'kunjeeranmyhero'}
# {'_id': 'tedbir'}
# {'_id': 'Fäkalsprache'}
# {'_id': 'modi'}
# {'_id': 'Kovid19'}
# {'_id': 'zachteheelmeester'}
# {'_id': 'MoMa'}
# {'_id': 'Großspender'}
# {'_id': 'viruscorona'}
# {'_id': 'Kindern'}
# {'_id': 'Wantagh'}
# {'_id': 'Comoundragon'}
# {'_id': 'nowplaying'}
# {'_id': 'TrumpIsNotADoctor'}
# {'_id': 'OpenAtMyHighRisk'}
# {'_id': 'resim'}
# {'_id': 'india'}
# {'_id': 'winnews'}
# {'_id': 'NHK徳島'}
# {'_id': 'rauchfrei'}
# {'_id': 'CoronaVirusKaimurBhabua'}
# {'_id': 'alcore'}
# {'_id': 'gbp'}
# {'_id': 'PejuangLdr'}
# {'_id': 'mujer'}
# {'_id': 'medical'}
# {'_id': 'sosyalmesafe'}
# {'_id': 'COVID_19uk'}
# {'_id': 'KSA'}
# {'_id': 'folio'}
# {'_id': 'heshestry'}
# {'_id': 'UNTUK'}
# {'_id': '2getherseries'}
# {'_id': 'Linder'}
# {'_id': 'kebetu'}
# {'_id': 'funnyquotes'}
# {'_id': 'UnDíaComoHoy'}
# {'_id': 'EUvsVirusHackathon'}
# {'_id': 'Mundschutzträger'}
# {'_id': 'GodMorningThursday'}
# {'_id': 'FridayThoughts'}
# {'_id': 'rt'}
# {'_id': 'trolleyrage'}
# {'_id': 'Mahnwache'}
# {'_id': '美容室のコロナ影響と対策'}
# {'_id': 'CoronaInfoCH'}
# {'_id': 'Jodhpur'}
# {'_id': 'bareback'}
# {'_id': 'gfvip'}
# {'_id': 'AKIBAT'}
# {'_id': 'himalayas'}
# {'_id': 'Maske'}
# {'_id': 'Xvideos'}
# {'_id': 'WTFU'}
# {'_id': 'RaizerOnline'}
# {'_id': 'Lockdownextention'}
# {'_id': 'Klimaaktivisten'}
# {'_id': 'toystory'}
# {'_id': 'नियमित_नर्सेज_भर्ती_2018_की_नियुक्ति_दो'}
# {'_id': 'CoronaPD'}
# {'_id': 'beertime'}
# {'_id': 'SAMACHARWALA'}
# {'_id': 'BIHK'}
# {'_id': 'explore'}
# {'_id': 'பஞ்சாபில்'}
# {'_id': 'S386IsGoodForAmerica'}
# {'_id': 'WithMe'}
# {'_id': 'Weltpolitik'}
# {'_id': 'KanyeWest'}
# {'_id': 'pietmondriaan'}
# {'_id': 'digr_io'}
# {'_id': 'DISINFECTION'}
# {'_id': 'myfirstTweet'}
# {'_id': 'RegulariseWithoutPPSC'}
# {'_id': 'CoronaGünlükleri'}
# {'_id': 'LetsTalkEducation'}
# {'_id': 'Saison'}
# {'_id': 'CoronaLockDown'}
# {'_id': 'Jabalpur'}
# {'_id': 'Mixer'}
# {'_id': 'dinerthuis'}
# {'_id': 'huurverhoging'}
# {'_id': 'Regeringsplan'}
# {'_id': 'दप्रिंट_दलाल_है'}
# {'_id': 'memories'}
# {'_id': 'levothyrox'}
# {'_id': 'EndFGM'}
# {'_id': 'Kirchen'}
# {'_id': 'SobatLumajang'}
# {'_id': 'RIPHumanity'}
# {'_id': 'BlackHistoryMonth'}
# {'_id': 'CORONA'}
# {'_id': 'Sénégal'}
# {'_id': 'huurtoeslag'}
# {'_id': 'Mohon'}
# {'_id': 'Bisexuell'}
# {'_id': 'eisgehtimmer'}
# {'_id': 'Eptv1'}
# {'_id': 'Maghar'}
# {'_id': 'drawing'}
# {'_id': 'twitterlehrerzimmer'}
# {'_id': 'mondkapjesgate'}
# {'_id': 'CoronaWorrierCableOperator'}
# {'_id': 'Bankers_mankibaat'}
# {'_id': 'GroKo'}
# {'_id': 'fashiongram'}
# {'_id': 'IAW2020'}
# {'_id': 'Jaffna'}
# {'_id': 'TLX_WEB15'}
# {'_id': 'thegoodsummit'}
# {'_id': 'VoteBlueToSaveAmerica'}
# {'_id': '25deabrilsempre'}
# {'_id': 'NiteshHelpKota'}
# {'_id': 'Hydroxichloriquin'}
# {'_id': 'Varsities'}
# {'_id': 'IQRTG'}
# {'_id': 'ZimAgainstCovid19'}
# {'_id': 'tezos'}
# {'_id': 'SultanNTRBdayMonthCDP'}
# {'_id': 'vcsbugil'}
# {'_id': 'सविताकोविंद'}
# {'_id': 'nome'}
# {'_id': 'DP3T'}
# {'_id': 'Röttgen'}
# {'_id': 'PMModi'}
# {'_id': 'uraniumtransport'}
# {'_id': 'Amtszeit'}
# {'_id': 'Aşk101'}
# {'_id': 'GraciasExtra'}
# {'_id': 'BETRIEB'}
# {'_id': 'funnymeme'}
# {'_id': '200_Cas'}
# {'_id': 'goodmorning'}
# {'_id': 'Exclusive'}
# {'_id': 'handpainted'}
# {'_id': 'suspension'}
# {'_id': 'ان_تكون_اولا'}
# {'_id': '28thfeb2020'}
# {'_id': 'PotsPanProtest'}
# {'_id': 'Ölüm'}
# {'_id': 'TigerKing'}
# {'_id': '打首獄門同好会'}
# {'_id': 'godmorningSaturday'}
# {'_id': 'hotspots'}
# {'_id': 'Kejriwal'}
# {'_id': 'TukdeTukdeGang'}
# {'_id': 'Malegaon'}
# {'_id': 'exponentiële'}
# {'_id': 'coronapocolypse'}
# {'_id': 'GOT7_NOTBYTHEMOON'}
# {'_id': 'CocuyoChequea'}
# {'_id': 'MP'}
# {'_id': 'NEWS'}
# {'_id': 'RD'}
# {'_id': 'Demonstrationen'}
# {'_id': 'k'}
# {'_id': 'vibe'}
# {'_id': 'ayoJogoJeporo'}
# {'_id': 'TelanganaFightsCorona'}
# {'_id': 'ParshuramJayanti'}
# {'_id': 'ShivrajPanauti'}
# {'_id': 'picoloapp'}
# {'_id': 'COVID19Ghana'}
# {'_id': 'नारीशक्ती'}
# {'_id': 'ShirtsForSupport'}
# {'_id': 'संतरामपालजी_का_सत्संग_सुनें'}
# {'_id': 'indiawithpmmodi'}
# {'_id': 'WHOLiedPeopleDied'}
# {'_id': 'shivrajsingh'}
# {'_id': 'CashMoneyFam'}
# {'_id': 'योग_से_युग_परिवर्तन'}
# {'_id': 'smallstreamersconnect'}
# {'_id': 'Arminlasset'}
# {'_id': 'Chomsky'}
# {'_id': 'COVID2019de'}
# {'_id': 'ergotherapeuten'}
# {'_id': 'CoronaPandemie'}
# {'_id': 'indianoccupied'}
# {'_id': 'Patanjali'}
# {'_id': 'Palaghar'}
# {'_id': 'SaturdayMotivation'}
# {'_id': 'CoronaTech'}
# {'_id': 'Academicsession'}
# {'_id': 'pipolitikspezial'}
# {'_id': 'Kreuzberg'}
# {'_id': 'CM'}
# {'_id': 'repu'}
# {'_id': 'maisach'}
# {'_id': 'Punjab'}
# {'_id': 'moreEurope'}
# {'_id': 'Merak'}
# {'_id': 'NoidaSector45'}
# {'_id': 'Tamilnews'}
# {'_id': 'CoronaInMaharashtra'}
# {'_id': 'YouTuber'}
# {'_id': 'ஜனாதிபதி_ஊடகப்பிரிவு'}
# {'_id': 'DijitalGelecek'}
# {'_id': 'பெரம்பலூர்'}
# {'_id': 'قطر_الخيرية'}
# {'_id': 'IndiansStuckAbroad'}
# {'_id': 'Nashville'}
# {'_id': 'hurst'}
# {'_id': 'NizamabadNews'}
# {'_id': 'योग'}
# {'_id': 'cumtribute'}
# {'_id': 'ONEOKROCKOnlineConcert'}
# {'_id': 'laatjenietprikken'}
# {'_id': 'ಅಂತ್ಯಸಂಸ್ಕಾರ'}
# {'_id': 'KiTas'}
# {'_id': 'foundonwalk'}
# {'_id': 'RKI'}
# {'_id': 'Finland'}
# {'_id': 'bjp'}
# {'_id': 'Finnish'}
# {'_id': 'AndroidStudio'}
# {'_id': 'News18Bangla'}
# {'_id': 'Cm'}
# {'_id': 'agenpkv'}
# {'_id': 'MaskGate'}
# {'_id': 'Italie'}
# {'_id': 'teatime'}
# {'_id': 'CoronavirusUSA'}
# {'_id': 'laban'}
# {'_id': 'FACEBOOK_LIVE_SERIES'}
# {'_id': 'Wiederaufbau'}
# {'_id': 'PTI'}
# {'_id': 'Consultant'}
# {'_id': 'ஊரடங்கு'}
# {'_id': 'Stimulusdeposit'}
# {'_id': 'Geheimsache'}
# {'_id': 'PISCINE'}
# {'_id': 'Sars'}
# {'_id': 'FechadoComBolsonaroAté2026'}
# {'_id': 'NitishHelpKota'}
# {'_id': 'सोनिया_गांधी'}
# {'_id': 'JennyWright'}
# {'_id': 'تطبيق_رواتب_السعودية'}
# {'_id': 'CoronaFund'}
# {'_id': 'audiozelfbouw'}
# {'_id': 'dresden'}
# {'_id': 'astma'}
# {'_id': 'VoteRedToSaveAmerica2020'}
# {'_id': 'SignsYoureACOVIDIOT'}
# {'_id': 'TweetYouSinners'}
# {'_id': 'माननीय'}
# {'_id': 'BekirKELLECİ'}
# {'_id': 'Kontrollen'}
# {'_id': 'footballismyreligion'}
# {'_id': 'Major2nd'}
# {'_id': 'Ahrweiler'}
# {'_id': 'soil'}
# {'_id': 'Agartala'}
# {'_id': 'lockdownphotography'}
# {'_id': 'ramazankafa'}
# {'_id': 'Gujarat'}
# {'_id': 'ShoMusicFestival'}
# {'_id': 'Hyderabad'}
# {'_id': '25aprile'}
# {'_id': 'Fundingtweets'}
# {'_id': 'رجل_التواصل_العالمي'}
# {'_id': 'conanisoverparty'}
# {'_id': 'NIET'}
# {'_id': 'marketing'}
# {'_id': 'moneyonroad'}
# {'_id': 'press'}
# {'_id': 'jeugd'}
# {'_id': 'Statusbericht'}
# {'_id': 'Respect'}
# {'_id': 'Bildung'}
# {'_id': 'Seelsorge'}
# {'_id': 'TeamMudik'}
# {'_id': 'encinitas'}
# {'_id': 'skymission'}
# {'_id': 'BleachTrump'}
# {'_id': 'الشهر_الفضيل'}
# {'_id': 'muarabulian'}
# {'_id': 'StopCovid'}
# {'_id': 'World'}
# {'_id': 'Einkaufsgutscheine'}
# {'_id': 'sarcasm'}
# {'_id': 'musnah'}
# {'_id': 'Ankleshwar'}
# {'_id': 'गाजियाबाद'}
# {'_id': 'wuhanVirus'}
# {'_id': 'LifeInsurance'}
# {'_id': '飛沫感染'}
# {'_id': 'Complexity'}
# {'_id': 'DKJNEWS'}
# {'_id': 'arrestarnabgoswami'}
# {'_id': 'DIRECTO'}
# {'_id': 'Ioannidis'}
# {'_id': 'biotechnology'}
# {'_id': 'PandemicCrisis'}
# {'_id': 'Free'}
# {'_id': 'SevillaHoy'}
# {'_id': 'Support'}
# {'_id': 'BalconySarkar'}
# {'_id': 'चित्तौड़गढ़'}
# {'_id': 'OnlineShop'}
# {'_id': 'magyar'}
# {'_id': 'pop'}
# {'_id': 'RNS'}
# {'_id': 'Rugby'}
# {'_id': 'HeineLesen'}
# {'_id': 'गुजरात'}
# {'_id': 'Eis'}
# {'_id': 'IMCBusinessGROUP'}
# {'_id': 'itsmycause'}
# {'_id': 'Iglesias'}
# {'_id': 'epa'}
# {'_id': 'यूपी'}
# {'_id': 'CoronavirusPandemic'}
# {'_id': 'コロナウィルス'}
# {'_id': 'travelmemories'}
# {'_id': 'devlet'}
# {'_id': 'kungsholmentweetup'}
# {'_id': 'CITWEndindthechas'}
# {'_id': 'bananabread'}
# {'_id': 'cerb'}
# {'_id': 'PMKISAN'}
# {'_id': 'ShaneIftar'}
# {'_id': 'CoronaVirusIndore'}
# {'_id': '25deAbril'}
# {'_id': 'UddhavThackeray'}
# {'_id': 'community'}
# {'_id': 'callcenter112'}
# {'_id': 'CoronavirusEnArgentina'}
# {'_id': 'coronafund'}
# {'_id': 'Bodi'}
# {'_id': 'D'}
# {'_id': 'மாடல்'}
# {'_id': 'spahnwill'}
# {'_id': 'CentralGovtEmployees'}
# {'_id': 'Livestreamburlesque'}
# {'_id': 'LockdownKeDushman'}
# {'_id': 'photography'}
# {'_id': 'cell'}
# {'_id': 'cegahbarengcovid19'}
# {'_id': 'SadhuKeHatyarokoBiryani'}
# {'_id': 'Backushome'}
# {'_id': 'catwoman'}
# {'_id': 'Malliard'}
# {'_id': 'Secularism'}
# {'_id': 'EHealth'}
# {'_id': 'knowledge'}
# {'_id': 'edecasa'}
# {'_id': 'LockdownLife'}
# {'_id': 'beers'}
# {'_id': 'Boston'}
# {'_id': 'Merkels'}
# {'_id': 'श्रीरामनवमी'}
# {'_id': 'Aviation'}
# {'_id': 'TrumpCrimeFamilyForPrison'}
# {'_id': 'thanos'}
# {'_id': 'trumpandemic'}
# {'_id': 'Xiaomi'}
# {'_id': 'Trennungseltern'}
# {'_id': 'スマートニュース'}
# {'_id': 'KF94'}
# {'_id': 'MAGA2020'}
# {'_id': 'SantAgatadeGoti'}
# {'_id': 'lessons'}
# {'_id': 'iostoacasa'}
# {'_id': 'IndianMuslimsInDanger'}
# {'_id': 'SmartNews'}
# {'_id': 'KAI'}
# {'_id': 'it'}
# {'_id': 'nayapura'}
# {'_id': 'Bankkaufmann'}
# {'_id': 'ACNH'}
# {'_id': 'SaturdayVibes'}
# {'_id': 'तमिलनाडु'}
# {'_id': 'bankersunited'}
# {'_id': 'crypto'}
# {'_id': 'LifeHack'}
# {'_id': 'PlusJamaisCa'}
# {'_id': 'allcelebreratiessupport'}
# {'_id': 'BasicIncomeNOW'}
# {'_id': 'Sábado'}
# {'_id': 'darknetflix'}
# {'_id': 'PLEASE'}
# {'_id': 'saudiarabia'}
# {'_id': 'dolar'}
# {'_id': 'Schulstart'}
# {'_id': 'aanpak'}
# {'_id': 'chinesevirus'}
# {'_id': 'illust'}
# {'_id': 'Findefix'}
# {'_id': 'aykutelmas'}
# {'_id': 'らくがき'}
# {'_id': 'RSS_KillingMuslims'}
# {'_id': 'EconomicCalendar'}
# {'_id': 'trt1'}
# {'_id': 'EIA2020'}
# {'_id': 'eurgbp'}
# {'_id': 'WorldwideTamils'}
# {'_id': 'quarantina'}
# {'_id': 'FUTURETALK'}
# {'_id': 'sivaji'}
# {'_id': 'FastNews'}
# {'_id': 'eConclave'}
# {'_id': 'AgraModel'}
# {'_id': 'ÖPNV'}
# {'_id': 'koningsdag'}
# {'_id': 'Tehran'}
# {'_id': 'COVID19fr'}
# {'_id': 'koronaNorge'}
# {'_id': 'AnzacDay2020'}
# {'_id': '12_नये_मामले'}
# {'_id': 'Söder'}
# {'_id': 'lovely_girl_shivani'}
# {'_id': 'besetzen'}
# {'_id': 'MakeChinaPay'}
# {'_id': 'Labor'}
# {'_id': 'moskee'}
# {'_id': 'coronajournal'}
# {'_id': 'موريتانيا_تحارب_كورونا'}
# {'_id': 'PPE'}
# {'_id': 'IndiaFightsCoronavirus'}
# {'_id': 'Aberglaube'}
# {'_id': 'Sta'}
# {'_id': 'TeamFinansial'}
# {'_id': 'IndiaStayHome'}
# {'_id': 'Ungarn'}
# {'_id': '25nisan'}
# {'_id': 'RamadhanKitaIstimewa'}
# {'_id': 'drive'}
# {'_id': 'Avezzano'}
# {'_id': 'fplus'}
# {'_id': 'bavette'}
# {'_id': 'owambe'}
# {'_id': 'Cantabria'}
# {'_id': 'Vladikavkaz'}
# {'_id': 'eglence'}
# {'_id': 'हिंदुओं'}
# {'_id': 'Entnazifizierung'}
# {'_id': 'niemalsCdu'}
# {'_id': 'Survivor'}
# {'_id': 'GMB'}
# {'_id': 'بومبيو'}
# {'_id': 'museums'}
# {'_id': 'football'}
# {'_id': 'yenivirüsCanan'}
# {'_id': 'Vidarbha'}
# {'_id': 'Charité'}
# {'_id': 'はてなブログ'}
# {'_id': 'CoronaWarriorsIndia'}
# {'_id': 'uk'}
# {'_id': 'ngmerecembuste'}
# {'_id': '25Nisan'}
# {'_id': 'Spanien'}
# {'_id': 'Sklaven'}
# {'_id': 'BongoFleva'}
# {'_id': 'VoteByMail2020'}
# {'_id': 'laughtogether'}
# {'_id': 'TemasTakip'}
# {'_id': 'EvdeKalHareketsizKalma'}
# {'_id': 'fortnumandmason'}
# {'_id': 'Vijay'}
# {'_id': 'bharat'}
# {'_id': 'Bapuji'}
# {'_id': 'reveluvselcaday'}
# {'_id': 'IPS'}
# {'_id': 'Spanishflu'}
# {'_id': 'viralnews'}
# {'_id': 'Gent'}
# {'_id': 'bleach'}
# {'_id': 'Meeraner'}
# {'_id': 'lockdownindia'}
# {'_id': 'moon'}
# {'_id': 'lka'}
# {'_id': 'salsa'}
# {'_id': 'FiqueEmCasa'}
# {'_id': 'Virus'}
# {'_id': 'पाकिस्तान'}
# {'_id': 'TwitterMemes'}
# {'_id': 'kfgbg'}
# {'_id': 'KYUHYUN'}
# {'_id': 'Marzahn'}
# {'_id': 'jambi'}
# {'_id': 'FollowTheScience'}
# {'_id': 'shutdown'}
# {'_id': 'koronavirus'}
# {'_id': 'Subscribe'}
# {'_id': 'coronarovirus'}
# {'_id': 'punkrockmidnight'}
# {'_id': 'चिकित्सा_पद्धति'}
# {'_id': 'आरोग्यसेतु'}
# {'_id': 'OEffnungsdiskussionsorgie'}
# {'_id': 'jerky'}
# {'_id': 'coronaHype'}
# {'_id': 'HosGeldinYaSehriRamazan'}
# {'_id': 'light'}
# {'_id': 'Wisconsin'}
# {'_id': 'ஆண்டாள்'}
# {'_id': 'CoronaVirusBhopal'}
# {'_id': 'cancer'}
# {'_id': 'onlyfansbabe'}
# {'_id': 'heldenvancorona'}
# {'_id': 'الذهاب'}
# {'_id': 'onlariçinevdekal'}
# {'_id': 'ramaphosa'}
# {'_id': 'CoronaWahn'}
# {'_id': 'BestTachaMoments'}
# {'_id': 'Why_Need_TrueWorship'}
# {'_id': 'Apple'}
# {'_id': 'ZEVAL'}
# {'_id': 'BVAP'}
# {'_id': 'الامارات'}
# {'_id': 'Saudi_Arabia'}
# {'_id': 'DropUAPACharges'}
# {'_id': 'IndianPolice'}
# {'_id': 'youcantfixstupid'}
# {'_id': 'stem'}
# {'_id': 'AntoniaMainoSonia'}
# {'_id': 'ContactTracing'}
# {'_id': 'uhuy'}
# {'_id': 'AlcolumbreInimigoDoBrasil'}
# {'_id': 'AgendaAajTak'}
# {'_id': 'artwork'}
# {'_id': 'ModiKiMKB'}
# {'_id': 'coronaApp'}
# {'_id': 'Breakingnews'}
# {'_id': 'govtech'}
# {'_id': 'DonaldTrump'}
# {'_id': 'IndiaStyle'}
# {'_id': 'Tierschutzhier'}
# {'_id': 'happyus'}
# {'_id': 'nature'}
# {'_id': 'Go'}
# {'_id': 'GreatAwakening'}
# {'_id': 'Grundrechte'}
# {'_id': 'Malaria'}
# {'_id': 'tidakmudik'}
# {'_id': 'Terrasse'}
# {'_id': 'Christen'}
# {'_id': 'CDC'}
# {'_id': 'influenza'}
# {'_id': 'bomdia'}
# {'_id': 'bjp_terrorist'}
# {'_id': 'shirts'}
# {'_id': 'go'}
# {'_id': 'TCID'}
# {'_id': 'backyardgarden'}
# {'_id': 'RepealUAPA'}
# {'_id': 'CRPFPosterChallenge'}
# {'_id': 'Geldstrafen'}
# {'_id': 'BluTV'}
# {'_id': 'slowdancing'}
# {'_id': 'رمضان_حي'}
# {'_id': 'bhfyp'}
# {'_id': 'आदिवासी'}
# {'_id': 'अधूरी_भर्तियां_पूरी_करो'}
# {'_id': 'Thalapathy'}
# {'_id': '香港'}
# {'_id': 'Nord'}
# {'_id': 'JuniorSambia'}
# {'_id': 'tutoring'}
# {'_id': 'Argentina'}
# {'_id': 'LOL'}
# {'_id': 'Hessen'}
# {'_id': 'Experten'}
# {'_id': 'sugardaddywanted'}
# {'_id': 'confinement'}
# {'_id': 'Landeselternrat'}
# {'_id': 'barbieisoverparty'}
# {'_id': 'Osten'}
# {'_id': 'PSBBSurabaya'}
# {'_id': 'TNTheatres'}
# {'_id': 'ZeeNews'}
# {'_id': 'Indonesia'}
# {'_id': 'wednesdaywisdom'}
# {'_id': 'EUBeiträge'}
# {'_id': 'RavishKumar'}
# {'_id': 'youtubedeutschland'}
# {'_id': 'socialmediamarketing'}
# {'_id': 'AndamansFightCovid19'}
# {'_id': 'gayproll'}
# {'_id': 'BalbirSidhu'}
# {'_id': 'LHWRF'}
# {'_id': 'TKI'}
# {'_id': 'weltbesteGöttergatte'}
# {'_id': 'AndamanAndNicobarIslands'}
# {'_id': 'mondkapjes'}
# {'_id': 'LockdownAwards'}
# {'_id': 'Bowie'}
# {'_id': 'VIRUS'}
# {'_id': 'AhmadiyyaJugend'}
# {'_id': 'nurgle'}
# {'_id': 'LEZ'}
# {'_id': 'Saisonabbruch'}
# {'_id': 'Panjtirthi'}
# {'_id': 'stupidtrump'}
# {'_id': 'cazzate'}
# {'_id': 'Balochistan'}
# {'_id': 'nursingschool'}
# {'_id': 'impleachtrump'}
# {'_id': '5words5tags'}
# {'_id': 'nomakeup'}
# {'_id': 'Daddylicious'}
# {'_id': 'APFightsCorona'}
# {'_id': 'aljazeera'}
# {'_id': 'Parashuram'}
# {'_id': 'babyyoda'}
# {'_id': 'Risikogruppe'}
# {'_id': 'Gurugram'}
# {'_id': 'isolation'}
# {'_id': 'Openscience'}
# {'_id': 'Kanchipuram'}
# {'_id': 'trending'}
# {'_id': 'நியூஸ்7தமிழ்'}
# {'_id': 'StayAtHomeSaveLives'}
# {'_id': 'Quarantäne'}
# {'_id': 'house'}
# {'_id': 'shiva'}
# {'_id': 'Justsaying'}
# {'_id': 'PMCaresFund'}
# {'_id': 'BreakTheChain'}
# {'_id': 'BlijfThuis'}
# {'_id': 'coronaリレー'}
# {'_id': 'Howrah'}
# {'_id': 'desinfektan'}
# {'_id': 'skrillex'}
# {'_id': 'Mundschutzpflicht'}
# {'_id': 'ISIS'}
# {'_id': 'Mietstundung'}
# {'_id': 'search'}
# {'_id': 'CoronaVirusFunny'}
# {'_id': 'المدينة_المنورة'}
# {'_id': 'Stadtjubiläum2020'}
# {'_id': 'bike'}
# {'_id': 'Hindi'}
# {'_id': 'istanbul'}
# {'_id': 'tariqjameel'}
# {'_id': 'cas'}
# {'_id': 'LadengeAurJeetenge'}
# {'_id': 'rock'}
# {'_id': 'Mike'}
# {'_id': 'aspiraționale'}
# {'_id': 'KillItWithFire'}
# {'_id': 'standupindo'}
# {'_id': 'CoronaBE'}
# {'_id': 'coronaviruslettertohumanity'}
# {'_id': 'namjin'}
# {'_id': 'Daten'}
# {'_id': 'Heinsbergstudie'}
# {'_id': 'syltereiscafe'}
# {'_id': '沖縄コロナ情報'}
# {'_id': 'Fußball'}
# {'_id': 'உயிர்காக்க_ஊரடங்கு'}
# {'_id': 'StadtFürAlle'}
# {'_id': 'stopmotion'}
# {'_id': 'Reproduktionsfaktor'}
# {'_id': 'BilimKurulu'}
# {'_id': 'SACHIN'}
# {'_id': 'dopefact'}
# {'_id': 'RamNavami'}
# {'_id': 'highgate'}
# {'_id': 'dj'}
# {'_id': 'TLX_Cargo'}
# {'_id': 'inittogether'}
# {'_id': 'meninges'}
# {'_id': 'atilimhukuk'}
# {'_id': 'cumslut'}
# {'_id': 'GatesFoundation'}
# {'_id': 'Innovationsprämien'}
# {'_id': 'oneofthe'}
# {'_id': 'Lyon'}
# {'_id': 'SooraraiPottru'}
# {'_id': 'SaudiArabia'}
# {'_id': 'YIAYgirl'}
# {'_id': 'research'}
# {'_id': 'Mehulvyas'}
# {'_id': 'BulliedBoy'}
# {'_id': 'RobinVos'}
# {'_id': 'funnymemes'}
# {'_id': 'JokoWidodo'}
# {'_id': 'Pride'}
# {'_id': 'Rip'}
# {'_id': 'Racism'}
# {'_id': 'AWARENESS'}
# {'_id': 'sadhguru'}
# {'_id': 'influencer'}
# {'_id': 'coronainadhra'}
# {'_id': 'UttarPradesh'}
# {'_id': 'Cricket'}
# {'_id': 'HerdImmunity'}
# {'_id': 'detmold'}
# {'_id': 'disinfectant'}
# {'_id': 'नमन'}
# {'_id': 'trading'}
# {'_id': 'Krösche'}
# {'_id': 'sanitizer'}
# {'_id': 'hindutemples'}
# {'_id': 'SanitationWarriors'}
# {'_id': 'KuchenAtHome'}
# {'_id': 'Research'}
# {'_id': 'WhatIMissAboutSports'}
# {'_id': 'dietitian'}
# {'_id': 'FaisLeVide'}
# {'_id': 'jobs'}
# {'_id': '国家破壊分子'}
# {'_id': 'Hotstar'}
# {'_id': 'DDR'}
# {'_id': 'liberazione'}
# {'_id': 'विविधभारती'}
# {'_id': 'AhmadiyyatisnotIslam'}
# {'_id': 'artofvisuals'}
# {'_id': 'BersamaLawanCorona'}
# {'_id': 'ZuannaLover'}
# {'_id': 'OnlyFansPromo'}
# {'_id': 'geçmiş'}
# {'_id': 'PuneFightsCorona'}
# {'_id': 'vatanmeselesi'}
# {'_id': 'coronavirusnobrasil'}
# {'_id': 'IslamRamah'}
# {'_id': 'vicces'}
# {'_id': 'CoronaVirusPakistan'}
# {'_id': 'AambaMahotsav'}
# {'_id': 'MinistryOfSocialAffairsAndHealth'}
# {'_id': 'Abra'}
# {'_id': 'Calvados'}
# {'_id': 'Zitat'}
# {'_id': 'death'}
# {'_id': 'Gabon'}
# {'_id': 'mumbai'}
# {'_id': 'covidindiatracker'}
# {'_id': 'ineedtiktok'}
# {'_id': 'etsyshop'}
# {'_id': 'shotonnikon'}
# {'_id': 'Ahokyere'}
# {'_id': 'கபசுர_குடிநீர்'}
# {'_id': 'testamentos'}
# {'_id': 'தமிழகம்'}
# {'_id': 'turkiye'}
# {'_id': 'Care'}
# {'_id': 'FilmYourHospital'}
# {'_id': '3M'}
# {'_id': 'Liberazione'}
# {'_id': 'Ahmadiyya'}
# {'_id': 'healthproduct'}
# {'_id': 'tuborg'}
# {'_id': 'BalsenaFightsCorona'}
# {'_id': '코로나19'}
# {'_id': 'coronafunerals'}
# {'_id': 'ValidNih'}
# {'_id': 'Empowerment'}
# {'_id': 'manga'}
# {'_id': 'Soral'}
# {'_id': 'Boycott'}
# {'_id': 'स्वदेशीसंकल्पदिवस'}
# {'_id': 'Reopen'}
# {'_id': 'mmt4indonesia'}
# {'_id': 'VoteBlue2020'}
# {'_id': 'infoviral'}
# {'_id': 'DIgitalisierung'}
# {'_id': 'Police'}
# {'_id': 'TOD'}
# {'_id': 'vacature'}
# {'_id': 'bangsatbangsa'}
# {'_id': 'NosQuedamosEnCasa'}
# {'_id': 'Fantasy'}
# {'_id': 'कॉंग्रेस'}
# {'_id': 'FoodforAll'}
# {'_id': 'ripfear'}
# {'_id': 'coronatest'}
# {'_id': 'Polizei'}
# {'_id': 'Game'}
# {'_id': 'Selbstständige'}
# {'_id': 'Welt'}
# {'_id': 'itscoronatime'}
# {'_id': 'Ho'}
# {'_id': 'BanIslam'}
# {'_id': 'ATM'}
# {'_id': 'untilwemeetagain'}
# ...
# {'_id': 'coronav'}
# {'_id': 'Walter'}
# {'_id': 'polsekpacet'}
# {'_id': 'lassankatadka'}
# {'_id': 'CoronaWarrior'}
# {'_id': 'Sprache'}
# {'_id': 'vidabesta'}
# {'_id': 'QuietDown'}
# {'_id': 'femmes'}
# {'_id': 'Beyhadh2'}
# {'_id': 'sports'}
# {'_id': 'Spor'}
# {'_id': 'Hotel'}
# {'_id': 'Zast'}
# {'_id': 'quatsch'}
# {'_id': 'Lockdown2020'}
# {'_id': 'Arcuri'}
# {'_id': 'CovidCampus'}
# {'_id': 'gayscally'}
# {'_id': 'Erntehelfer'}
# {'_id': 'Reiche'}
# {'_id': 'Lake'}
# {'_id': 'PRC'}
# {'_id': 'Journals'}
# {'_id': 'NewsDigest'}
# {'_id': 'Duitser'}
# {'_id': 'patientendaten'}
# {'_id': 'CoronavirusUpdate'}
# {'_id': 'navgujaratsamay'}
# {'_id': 'NTPC'}
# {'_id': 'COVID19Karnataka'}
# {'_id': 'masques'}
# {'_id': 'माननीयमोदीजी'}
# {'_id': 'groepsimmuniteit'}
# {'_id': 'coronamemes'}
# {'_id': 'mislims'}
# {'_id': 'MissionAarogyaSetu'}
# {'_id': 'Stanford'}
# {'_id': 'amor'}
# {'_id': 'grape'}
# {'_id': 'Contest'}
# {'_id': 'mahakal'}
# {'_id': 'CovidVirus'}
# {'_id': 'information'}
# {'_id': 'NamasteTrump'}
# {'_id': 'PresidenteMattarella'}
# {'_id': 'Großclans'}
# {'_id': 'OneNightWithRegine'}
# {'_id': 'PMCARES'}
# {'_id': 'Prediction'}
# {'_id': '一緒に戦いましょう'}
# {'_id': 'コロナ感染者'}
# {'_id': 'YaygınTestÜcretliİzin'}
# {'_id': 'かっこいい'}
# {'_id': 'PollOfTheDay'}
# {'_id': 'society'}
# {'_id': 'Papalotla'}
# {'_id': 'Valimai'}
# {'_id': 'Indigo'}
# {'_id': 'prutsers'}
# {'_id': 'minutemen'}
# {'_id': 'ホテル'}
# {'_id': 'DisneyWorld'}
# {'_id': 'toaru'}
# {'_id': 'Gebauer'}
# {'_id': 'drawings'}
# {'_id': 'Thalassemia'}
# {'_id': 'iphone'}
# {'_id': 'ndma'}
# {'_id': 'meditation'}
# {'_id': 'money'}
# {'_id': 'Partnerschaftsgewalt'}
# {'_id': 'Sidnaaz'}
# {'_id': 'CoronaVirusHoshangabad'}
# {'_id': 'kpopisoverparty'}
# {'_id': 'Bill'}
# {'_id': 'VERIFIED'}
# {'_id': 'ObatTradisional'}
# {'_id': 'dinakaran'}
# {'_id': 'blog'}
# {'_id': 'SANSHINYUIMARU'}
# {'_id': 'ShopeeGiveawayHP'}
# {'_id': 'Paris'}
# {'_id': 'osmanmueftueoğlunasorun'}
# {'_id': 'TamilNaduLockdown'}
# {'_id': 'naturalhair'}
# {'_id': 'Mittelalter'}
# {'_id': 'JessicaIskandar'}
# {'_id': 'WhaModijiWha'}
# {'_id': 'Norditalien'}
# {'_id': 'omgangsregeling'}
# {'_id': 'GermanGP'}
# {'_id': 'RespectCoronaWarriors'}
# {'_id': 'Islam'}
# {'_id': 'Genocide'}
# {'_id': 'korttwitters'}
# {'_id': 'Familienkompass'}
# {'_id': 'CoRoNa'}
# {'_id': 'Pflegende'}
# {'_id': 'leaf'}
# {'_id': 'AlfonsScholing'}
# {'_id': 'wontstop'}
# {'_id': 'ES'}
# {'_id': '航空券'}
# {'_id': 'PALESTRE'}
# {'_id': 'KutchDefeatsCorona'}
# {'_id': 'WWG1WGAWORLDWIDE'}
# {'_id': 'issoaglobonãomostra'}
# {'_id': 'LSA'}
# {'_id': 'Tag_des_Baumes'}
# {'_id': 'WhiteHouse'}
# {'_id': 'ForaBolsonaroS'}
# {'_id': 'ワーホリ'}
# {'_id': 'doing'}
# {'_id': 'WA'}
# {'_id': 'Personalmangel'}
# {'_id': 'OpenCalifornia'}
# {'_id': '9gag'}
# {'_id': 'familytime'}
# {'_id': 'children'}
# {'_id': 'D66'}
# {'_id': 'vot24x7'}
# {'_id': 'gouvernement'}
# {'_id': 'UNITEDagainstCorona'}
# {'_id': 'OR'}
# {'_id': 'सूरत'}
# {'_id': 'kapper'}
# {'_id': 'Leipzig'}
# {'_id': 'Nizamabad'}
# {'_id': 'WeDemandStipendincrement'}
# {'_id': 'Erwachen'}
# {'_id': 'Çin'}
# {'_id': 'headwrap'}
# {'_id': 'coronaart'}
# {'_id': 'PakistanFightsCorona'}
# {'_id': 'Gedicht'}
# {'_id': 'Dirumahaja'}
# {'_id': 'Gastronomen'}
# {'_id': 'anggur'}
# {'_id': 'coronaturkiye'}
# {'_id': 'eAgendaAajTak'}
# {'_id': 'ContestAlert'}
# {'_id': 'stop'}
# {'_id': 'RazerStreamer'}
# {'_id': 'نحسبها_بالعقل_خامسه_طب_نقل'}
# {'_id': 'kebijakan2'}
# {'_id': 'Transformation'}
# {'_id': 'Kotlin'}
# {'_id': 'Bank'}
# {'_id': 'unsignedmusician'}
# {'_id': 'Whirlpool'}
# {'_id': 'CoronaInBadlapur'}
# {'_id': 'digitalHealth'}
# {'_id': 'Idaho'}
# {'_id': 'Rey'}
# {'_id': 'stayhomestaysafe'}
# {'_id': 'affirmations'}
# {'_id': 'cull'}
# {'_id': 'keineprüfung'}
# {'_id': 'GOT7'}
# {'_id': 'FAHAMU'}
# {'_id': '1MonthLockdownWithoutPlan'}
# {'_id': 'breakup'}
# {'_id': 'CoronaBeard'}
# {'_id': 'JammuAndKashmir'}
# {'_id': 'journalist'}
# {'_id': 'protectYourselF'}
# {'_id': 'StonesAtHome'}
# {'_id': 'Cronavirus'}
# {'_id': 'OilPrice'}
# {'_id': 'pharmacist'}
# {'_id': 'CoronaResearch'}
# {'_id': '5G'}
# {'_id': 'Covidunity'}
# {'_id': 'MORONAVIRUS'}
# {'_id': '西村大臣'}
# {'_id': 'TheBravest'}
# {'_id': 'EUvsVirus'}
# {'_id': 'Nuernbeg'}
# {'_id': 'FunctionCreep'}
# {'_id': 'Nifty'}
# {'_id': 'Disoccupati'}
# {'_id': 'CoronaVirusAT'}
# {'_id': 'DunyaVeterinerHekimlerGunu'}
# {'_id': 'richpokerqq'}
# {'_id': 'Urgente'}
# {'_id': 'deafspraak'}
# {'_id': 'times'}
# {'_id': 'Facts'}
# {'_id': 'SRFtrend'}
# {'_id': 'Ahmedabad'}
# {'_id': 'Repubtards'}
# {'_id': 'Throwbackthursday'}
# {'_id': 'sandiego'}
# {'_id': 'Coro'}
# {'_id': 'DontGoViral'}
# {'_id': 'worst'}
# {'_id': 'LocalsVsCorona'}
# {'_id': 'film'}
# {'_id': 'Touch'}
# {'_id': 'Klimapolitik'}
# {'_id': 'simplysaxony'}
# {'_id': 'sisterhood'}
# {'_id': 'EUschulddeling'}
# {'_id': 'Klopapier'}
# {'_id': 'JDS'}
# {'_id': 'réunies'}
# {'_id': 'delft'}
# {'_id': 'Tnreports'}
# {'_id': 'ImtiazAli'}
# {'_id': 'mundschutzpflicht'}
# {'_id': 'PsychoSaro'}
# {'_id': 'yamuna'}
# {'_id': 'دريمة'}
# {'_id': 'ArjaLaitinen'}
# {'_id': 'humanity'}
# {'_id': 'WORLDMUSIC'}
# {'_id': 'sachsensdemokratie'}
# {'_id': 'ERA'}
# {'_id': 'geschichte'}
# {'_id': 'coronavirusindia'}
# {'_id': 'PonyVPN'}
# {'_id': 'pandemic2020'}
# {'_id': 'filmincolorado'}
# {'_id': 'justsaying'}
# {'_id': 'madrid'}
# {'_id': 'Probleme'}
# {'_id': 'nashik'}
# {'_id': 'hogwartscrest'}
# {'_id': 'tamilnadu'}
# {'_id': 'SalmanKhan'}
# {'_id': 'vrmm'}
# {'_id': 'RegulariseBefore30April'}
# {'_id': 'croatia'}
# {'_id': '神奈川県医師会'}
# {'_id': 'triage'}
# {'_id': 'archaeologist'}
# {'_id': 'Beleidigungen'}
# {'_id': 'Rassismus'}
# {'_id': '7DODM'}
# {'_id': 'HumNews'}
# {'_id': 'Southport'}
# {'_id': 'puglia'}
# {'_id': 'SağlıkcılarınıAlkısla'}
# {'_id': 'marcvanranst'}
# {'_id': 'Pakistani'}
# {'_id': 'AvengersEndgame'}
# {'_id': 'LivedoMioto'}
# {'_id': 'app'}
# {'_id': 'Foottwearmall'}
# {'_id': 'fuckme'}
# {'_id': 'Poverty'}
# {'_id': 'help'}
# {'_id': 'mizahruhu'}
# {'_id': 'राजस्थान'}
# {'_id': 'bvc'}
# {'_id': 'Reality'}
# {'_id': 'SmartPune'}
# {'_id': 'aaru'}
# {'_id': 'toename'}
# {'_id': 'aabee'}
# {'_id': 'Job'}
# {'_id': 'traveler'}
# {'_id': 'Pamela'}
# {'_id': 'Spiegel'}
# {'_id': 'newblog'}
# {'_id': 'Covid19InIran'}
# {'_id': 'PANdemic2020'}
# {'_id': 'CoronaVirusIndia'}
# {'_id': 'CoronaAlert'}
# {'_id': 'jokes'}
# {'_id': 'Fahndungsliste'}
# {'_id': 'testamentoonline'}
# {'_id': 'WorkFromHome'}
# {'_id': 'city'}
# {'_id': 'MaharashtraWithCM'}
# {'_id': 'worldpeace'}
# {'_id': 'Bengal'}
# {'_id': 'HayatEveSığar'}
# {'_id': 'breakfast'}
# {'_id': 'TomHanks'}
# {'_id': 'عُمان'}
# {'_id': 'مدريد'}
# {'_id': 'Brandbeschleuniger'}
# {'_id': 'OdishaUnderLockdown'}
# {'_id': 'Maharashtralockdown'}
# {'_id': 'Schwanz'}
# {'_id': 'mask'}
# {'_id': 'الكويت'}
# {'_id': 'cases'}
# {'_id': 'Twitch'}
# {'_id': 'Ambala'}
# {'_id': 'Festival'}
# {'_id': 'BlueTwitter'}
# {'_id': 'CoronaInBharatpur'}
# {'_id': 'HNEE'}
# {'_id': 'HinduphobicJharkhandPolice'}
# {'_id': 'maconha'}
# {'_id': 'SPDbewegt'}
# {'_id': 'Nationalismus'}
# {'_id': 'LBCINews'}
# {'_id': 'dijitalbasınileoku'}
# {'_id': 'Oldambt'}
# {'_id': 'words'}
# {'_id': 'Holzpreis'}
# {'_id': 'lab_assistent_2018'}
# {'_id': 'GOPCorruptionOverCountry'}
# {'_id': 'Vadodara'}
# {'_id': 'buffalo'}
# {'_id': 'coronaentertainment'}
# {'_id': 'miamistreetforlife'}
# {'_id': 'Poetry'}
# {'_id': 'coronavirusnl'}
# {'_id': 'Fiverr'}
# {'_id': 'MahmutDölek'}
# {'_id': 'Rohöl'}
# {'_id': 'Boulder'}
# {'_id': 'cilacap'}
# {'_id': 'evacuation'}
# {'_id': 'Ahemdabad'}
# {'_id': 'I'}
# {'_id': 'iran'}
# {'_id': 'runganSport'}
# {'_id': 'MSM'}
# {'_id': 'NewYorker'}
# {'_id': 'Klimawandel'}
# {'_id': 'RIP'}
# {'_id': 'cornoravirus'}
# {'_id': 'AhunaUhana'}
# {'_id': 'MissYouAll'}
# {'_id': 'المملكة'}
# {'_id': 'belirumah'}
# {'_id': 'retweet'}
# {'_id': 'ÖNEMLİ'}
# {'_id': 'fossil'}
# {'_id': 'Berichterstattung'}
# {'_id': 'jugendweihe'}
# {'_id': 'travel'}
# {'_id': 'patrikaCoronaLATEST'}
# {'_id': 'TogetherAtHome'}
# {'_id': 'Quaraintine'}
# {'_id': 'messy'}
# {'_id': 'कोरोना_वायरस'}
# {'_id': 'thedonald'}
# {'_id': 'WorldHealthOrganization'}
# {'_id': 'morattusingle'}
# {'_id': 'convid19'}
# {'_id': 'puzzles'}
# {'_id': 'EnvatoMarket'}
# {'_id': 'RDPLJaipur'}
# {'_id': 'kya'}
# {'_id': 'ÖDP'}
# {'_id': 'hopelessmodi'}
# {'_id': 'Prayagraj'}
# {'_id': 'challenge'}
# {'_id': 'huntingseason'}
# {'_id': 'PideAlmayaDiyeCıkıp'}
# {'_id': 'RamNavami2020'}
# {'_id': 'timesnow'}
# {'_id': 'motuaurpatlu'}
# {'_id': 'アベノマスクいらない'}
# {'_id': 'homeinspection'}
# {'_id': 'Team_Amani'}
# {'_id': 'Bailout'}
# {'_id': 'Bulletin'}
# {'_id': 'PresidentialMedal'}
# {'_id': 'IKnewIWasHurtWhen'}
# {'_id': 'RayWinstone'}
# {'_id': 'bandartogel'}
# {'_id': 'socialmediamanager'}
# {'_id': 'Boothbay'}
# {'_id': 'kitchen'}
# {'_id': 'RoadTo10WithALDEN'}
# {'_id': 'musica'}
# {'_id': 'Jio'}
# {'_id': 'zeiklozezaterdag'}
# {'_id': 'Gallery'}
# {'_id': 'Altersschwäche'}
# {'_id': 'cartoon'}
# {'_id': 'Wilmes'}
# {'_id': 'WelcomeTo2020'}
# {'_id': 'Palette'}
# {'_id': 'Beethoven'}
# {'_id': 'dogs'}
# {'_id': 'cake'}
# {'_id': 'Roedl'}
# {'_id': 'RheinischerKlüngel'}
# {'_id': 'FlattenBothCurves'}
# {'_id': '自粛疲れ'}
# {'_id': 'tshirt'}
# {'_id': 'AUSNAHMEZUSTAND'}
# {'_id': 'کورونا'}
# {'_id': 'Ruhrgebiet'}
# {'_id': 'PuneFightsCovid19'}
# {'_id': 'Jaipur'}
# {'_id': 'Swedden'}
# {'_id': 'Mattarellarocks'}
# {'_id': 'Yasin'}
# {'_id': 'IPL2020'}
# {'_id': 'innovation'}
# {'_id': 'Lidl'}
# {'_id': 'CoronaCampaign'}
# {'_id': 'IndiaWithPmModi'}
# {'_id': 'ChinaVirus'}
# {'_id': 'CoronainIndia'}
# {'_id': 'CoronavirusOubreak'}
# {'_id': 'देश'}
# {'_id': 'BadenWürttemberg'}
# {'_id': 'Mustergesundheitsamt'}
# {'_id': 'musician'}
# {'_id': 'Ramzan2020'}
# {'_id': 'MaxPayne'}
# {'_id': 'esport'}
# {'_id': 'KoranoVirüs'}
# {'_id': 'donate'}
# {'_id': '沖縄に来ないで'}
# {'_id': 'TheLokniti'}
# {'_id': 'EvdeKalKitapOku'}
# {'_id': 'bloggers'}
# {'_id': 'StopCovod19App'}
# {'_id': 'PolriCegahCorona'}
# {'_id': 'LockdownHouseParty'}
# {'_id': 'DirumahBarengGTV'}
# {'_id': 'srilanka'}
# {'_id': 'izmir'}
# {'_id': 'Marvel'}
# {'_id': 'cementerio'}
# {'_id': 'CAA_NRC_NPR'}
# {'_id': 'ArunBaroka'}
# {'_id': 'EvdeKal'}
# {'_id': 'tundamudikcegahcorona'}
# {'_id': 'nisaboeluekbası'}
# {'_id': 'NoAfD'}
# {'_id': 'الغد'}
# {'_id': 'Allergie'}
# {'_id': 'forget'}
# {'_id': 'visualization'}
# {'_id': 'davranış'}
# {'_id': 'Dance'}
# {'_id': 'ThankQ'}
# {'_id': 'S386IsFair'}
# {'_id': 'stelletjesufferds'}
# {'_id': 'طالبان'}
# {'_id': 'pennsyltucky'}
# {'_id': 'DAForGovtEmployee'}
# {'_id': 'Verkehrswende'}
# {'_id': 'MSNBC'}
# {'_id': 'quaranqueefs'}
# {'_id': 'RevanthReddy'}
# {'_id': 'SL'}
# {'_id': 'Bloedserieus'}
# {'_id': 'facts'}
# {'_id': 'BadNeuenahr'}
# {'_id': 'beer'}
# {'_id': 'KRITIS'}
# {'_id': 'Who_Is_Real_SadGuru'}
# {'_id': 'konspirasi'}
# {'_id': 'BJPMLA'}
# {'_id': 'Nimbahera'}
# {'_id': 'Tierheime'}
# {'_id': 'tarih'}
# {'_id': 'rangpurerkantho'}
# {'_id': 'Homeschooling'}
# {'_id': 'religieusincoronatijd'}
# {'_id': 'BersamaKitaBisa'}
# {'_id': 'wirsindbeieuch'}
# {'_id': 'spanje'}
# {'_id': 'srfClub'}
# {'_id': 'FaceID'}
# {'_id': 'iamkunjeeran'}
# {'_id': 'PopupBikelanes'}
# {'_id': 'asthma'}
# {'_id': 'Mutation'}
# {'_id': 'Watzke'}
# {'_id': 'Uitwonendeouders'}
# {'_id': 'chhattisgarh'}
# {'_id': 'hinduphobia_in_jharkhand'}
# {'_id': 'ChinaMustPay'}
# {'_id': 'work_hazard'}
# {'_id': 'CoCos'}
# {'_id': 'BeHealth'}
# {'_id': 'FalseNews'}
# {'_id': 'OnTheRecord'}
# {'_id': 'Tebuscamos'}
# {'_id': 'mealsofhappiness'}
# {'_id': 'gender'}
# {'_id': 'coronavirusinpakistan'}
# {'_id': 'politika'}
# {'_id': 'Dettol'}
# {'_id': 'aycanyanac'}
# {'_id': 'Roma'}
# {'_id': 'bar'}
# {'_id': 'teodoros'}
# {'_id': 'ranaSana'}
# {'_id': 'CoronaVirusTamilNadu'}
# {'_id': 'heindekort'}
# {'_id': '歌ってみた'}
# {'_id': 'Ghana'}
# {'_id': 'vicceskepek'}
# {'_id': 'CPCforBankers'}
# {'_id': 'CoronaWarriors'}
# {'_id': 'NTR'}
# {'_id': 'MenToo'}
# {'_id': 'Storymaschine'}
# {'_id': 'life'}
# {'_id': 'translation'}
# {'_id': 'Bihar'}
# {'_id': 'COVID19NL'}
# {'_id': 'evenementen'}
# {'_id': 'Kurzarbeitergeld'}
# {'_id': 'رمضان_كريم'}
# {'_id': '2019nCoV'}
# {'_id': 'jahat'}
# {'_id': 'kwarapolyvsfedpoffa'}
# {'_id': 'RSS_terrorist_Organization'}
# {'_id': 'MemerSangh'}
# {'_id': 'koenzimq10'}
# {'_id': 'TriColores'}
# {'_id': 'GoCorona'}
# {'_id': 'BlueEagleNation'}
# {'_id': 'CNNSesameStreet'}
# {'_id': 'RepublicansAreKillingUs'}
# {'_id': 'fintech'}
# {'_id': 'Bautzen'}
# {'_id': 'ceza'}
# {'_id': 'sindhgovernment'}
# {'_id': 'TeriMitti'}
# {'_id': 'RepublicTV'}
# {'_id': 'covidcartoon'}
# {'_id': 'Allgäu'}
# {'_id': 'JudiOnline'}
# {'_id': 'ரத்து'}
# {'_id': 'straßenwaschendenJuden'}
# {'_id': 'Melbourne'}
# {'_id': 'komik'}
# {'_id': 'LINKE'}
# {'_id': 'kitasgeschlosen'}
# {'_id': 'katheterkollegen'}
# {'_id': 'INJESUSNAME'}
# {'_id': 'Sommer'}
# {'_id': 'CommunityChest'}
# {'_id': 'uni1'}
# {'_id': 'Flüchtlingslager'}
# {'_id': 'StrandedAndDying'}
# {'_id': 'srbija'}
# {'_id': 'Parody'}
# {'_id': 'stroke'}
# {'_id': 'lawancoronabersama'}
# {'_id': 'グルメ'}
# {'_id': 'SamanthaBirthdayCDP'}
# {'_id': 'NCYT'}
# {'_id': 'فلسطين'}
# {'_id': 'tinder'}
# {'_id': 'nofake'}
# {'_id': 'शादी'}
# {'_id': 'sapanegri'}
# {'_id': 'Pelabuhan'}
# {'_id': 'Maiyah'}
# {'_id': 'thegreatdays2020'}
# {'_id': 'schule'}
# {'_id': 'MainBhiCOVIDWarrior'}
# {'_id': 'Sonntag'}
# {'_id': 'CoronavirusPalermo'}
# {'_id': 'ALIANÇAPELOBRASIL'}
# {'_id': 'Pharmacist'}
# {'_id': 'PalgharMobLynching'}
# {'_id': 'rijswijk'}
# {'_id': 'Nikon'}
# {'_id': 'Sealing'}
# {'_id': '8Kun'}
# {'_id': '感染者'}
# {'_id': 'interview'}
# {'_id': 'AndamanFight'}
# {'_id': 'होली'}
# {'_id': 'republican'}
# {'_id': 'stuttgart'}
# {'_id': 'பாமக'}
# {'_id': 'helikopter'}
# {'_id': 'RT'}
# {'_id': 'Rutte3'}
# {'_id': 'PunjabGovernment'}
# {'_id': 'Chittorgarh'}
# {'_id': 'sexyphotos100'}
# {'_id': 'SUDUTinfo'}
# {'_id': 'strategy'}
# {'_id': 'TorontoPHO'}
# {'_id': 'Followayan'}
# {'_id': 'Deaths'}
# {'_id': 'VW'}
# {'_id': 'funnygirl'}
# {'_id': 'Dhule'}
# {'_id': 'Geburt'}
# {'_id': 'Habeck'}
# {'_id': 'heart'}
# {'_id': 'PROGRAM'}
# {'_id': 'northmcdकोरोना'}
# {'_id': 'vlog'}
# {'_id': 'CoronaVirusChallenge'}
# {'_id': 'china'}
# {'_id': 'GOODEWS'}
# {'_id': 'donation'}
# {'_id': 'SoCalledSecular'}
# {'_id': 'Italy'}
# {'_id': 'Islamophobia'}
# {'_id': 'Fussball'}
# {'_id': 'Smartmagic'}
# {'_id': 'GoogleAlerts'}
# {'_id': 'Social_Distancing'}
# {'_id': 'exitracism'}
# {'_id': '外出自粛'}
# {'_id': 'Baum'}
# {'_id': 'gambus'}
# {'_id': 'lindner'}
# {'_id': 'InlandEmpire'}
# {'_id': 'Argentinien'}
# {'_id': 'Terrorism'}
# {'_id': 'صامطة'}
# {'_id': 'doha'}
# {'_id': 'ProfessionalizeMicrobiology'}
# {'_id': 'MikeHuckaby'}
# {'_id': 'GBP'}
# {'_id': 'Viruscorona'}
# {'_id': 'GaddalakondaGanesh'}
# {'_id': 'Savefarmerfirst'}
# {'_id': 'daragonAu'}
# {'_id': 'FamiliaDeMiliciano'}
# {'_id': 'gaziantep'}
# {'_id': 'โควิด19'}
# {'_id': 'TrumpPandemic'}
# {'_id': 'shemalejogja'}
# {'_id': 'Jsp'}
# {'_id': 'vijayrupani'}
# {'_id': 'euro'}
# {'_id': 'patient'}
# {'_id': 'خيمة_التواصل_العالمية'}
# {'_id': 'BB13'}
# {'_id': 'showhaber'}
# {'_id': 'CharlotteSeck'}
# {'_id': 'sugarbaby'}
# {'_id': 'EIAforGreenIndia'}
# {'_id': 'BadoTunasongaTu'}
# {'_id': 'morrodemedodoCorona'}
# {'_id': 'PinarayiVijayan'}
# {'_id': 'CoronafreeZone'}
# {'_id': 'BeSmartBeSafe'}
# {'_id': 'TrumpIsALoser'}
# {'_id': 'SingleSource'}
# {'_id': 'FirstWorldProblems'}
# {'_id': 'BREKAKING'}
# {'_id': 'gasolina'}
# {'_id': 'CoronaVirusPunjab'}
# {'_id': 'BeB'}
# {'_id': 'PortoTorres'}
# {'_id': 'instagood'}
# {'_id': 'poén'}
# {'_id': 'Terrorist'}
# {'_id': 'remotemilitarymarch'}
# {'_id': 'Animals'}
# {'_id': 'johndorian'}
# {'_id': 'coronagolf'}
# {'_id': 'KenFM'}
# {'_id': 'Ramdan'}
# {'_id': 'werbung'}
# {'_id': 'ImprisonLeni2020'}
# {'_id': 'FRPBKudus'}
# {'_id': 'CMIIW'}
# {'_id': 'EducationMinisterGoesLive'}
# {'_id': 'happy'}
# {'_id': 'NOVAVAX'}
# {'_id': 'Mieterlass'}
# {'_id': 'SONDAKİKA'}
# {'_id': 'GOP'}
# {'_id': 'T2020JPM'}
# {'_id': 'IslamSolusiTuntas'}
# {'_id': 'coronabeer'}
# {'_id': 'ChinaCoverUp'}
# {'_id': 'LoveLikeRoksie'}
# {'_id': 'Stuttgart21'}
# {'_id': 'DenHaag'}
# {'_id': 'BolsonaroEnlouqueceu'}
# {'_id': 'Terpopuler'}
# {'_id': 'france'}
# {'_id': 'covidhoax'}
# {'_id': 'Military'}
# {'_id': 'CoronavirusIndonesia'}
# {'_id': 'WeShallOvercome'}
# {'_id': 'Dhaka'}
# {'_id': 'xxx'}
# {'_id': 'Obama'}
# {'_id': 'tariqjamil'}
# {'_id': 'Meppen'}
# {'_id': 'GurmeetRamRahim'}
# {'_id': 'スカイミッション'}
# {'_id': 'helicoptermoney'}
# {'_id': 'Zone'}
# {'_id': 'TablighiJamat'}
# {'_id': 'CoronaExit'}
# {'_id': 'NewDelhi'}
# {'_id': 'knittingcharts'}
# {'_id': 'Wachtkamerscherm'}
# {'_id': 'DiRumahAjaYa'}
# {'_id': 'digitalnews'}
# {'_id': 'firstcase'}
# {'_id': 'collectie'}
# {'_id': 'TrumpMeltdown'}
# {'_id': 'मराठी'}
# {'_id': 'akshaykumar'}
# {'_id': 'Hollywood'}
# {'_id': 'CassperStayAtHomeGames'}
# {'_id': 'UBI'}
# {'_id': 'karantinagunlukleri'}
# {'_id': 'Vírus'}
# {'_id': 'LosMásLeídos'}
# {'_id': 'feets'}
# {'_id': 'ArrestAntiIndiaArnab'}
# {'_id': 'PROP'}
# {'_id': 'bootech'}
# [NbConvertApp] Converting notebook MongoDB_Load_Data.ipynb to script
# [NbConvertApp] Writing 16074 bytes to MongoDB_Load_Data.py
# [NbConvertApp] Converting notebook Cache_Load_Data.ipynb to script
# [NbConvertApp] Writing 10572 bytes to Cache_Load_Data.py

# %%
cache={}
user_cache = {}
tweet_cache = {}
hashtag_cache = {}
filename = r'C:\Users\Yuqing Dai\Desktop\rutgers-ds\database\final project\cache.json'

cache = load_cache(filename)
if len(cache) > 0:
    user_cache  = cache.get('User',{})
    tweet_cache  = cache.get('Tweet',{})
    hashtag_cache  = cache.get('Hashtag',{})
    

    
    
    
def main(Type, string, limit=None, start_time=None, end_time=None):
    
    if Type == 'user':
        result = user_search(user_cache, string, limit)  # Func 5
        print(result)
        if isinstance(result, list):
            n = min(limit, len(result))
            json_data = json.dumps(result[:n])
            return json_data
    elif Type == 'text':
        result = string_search(tweet_cache, start_time, end_time, string, limit)
        print(result)# Func 1
        if isinstance(result, list):
            n = min(limit, len(result))
            json_data = json.dumps(result[:n])
            print(result)
            return json_data
           
        else:
            json_data = json.dumps(result)
            return json_data
    elif Type == 'hashtag':
        result = hashtag_search(hashtag_cache, start_time, end_time, string, limit)  # Func 2
        print(result)
        if isinstance(result, list):
            n = min(limit, len(result))
            json_data = json.dumps(result[:n])
            return json_data
        else:
            json_data = json.dumps(result)
            return json_data
    elif Type == 'author':
        screen_name = string
        result = get_tweets_by_screen_name(screen_name)
        print(result)
        json_data = json.dumps(result)
        return json_data
    elif Type == 'retweet':
        retweet_id = int(string)
        result = find_retweeters_by_tweet_id(retweet_id)
        print(result)
        json_data = json.dumps(result)
        return json_data
    else:
        print("Invalid search type:", Type)






    
    
    
def save_cache_to_disk():
    cache['User']=user_cache
    cache['Tweet']=tweet_cache
    cache['Hashtag']=hashtag_cache
    save_cache(cache,filename)
    
    
    
import time
def periodic_save(interval):
    while True:
        save_cache_to_disk()
        time.sleep(interval)

# Define the interval for periodic saving (e.g., every 10 seconds)
save_interval = 60

# Start the periodic saving process in a separate thread
import threading
save_thread = threading.Thread(target=periodic_save, args=(save_interval,))
save_thread.start()

# %%
Type = "author"     
string = 'bablusharmabjp'
json_data = json.dumps(main(Type,string))
print(type(json_data))
# Out:
# [['Sat Apr 18 04:20:02 +0000 2020', '*अंदर से कोई बाहर न जा सके*\n\n*बाहर से कोई अंदर न जा सके*\n\n*घर में रहे सेफ रहे*\n\n#corona  रूपी रावण को मारना है*\n\n#सुप्रभात #हेलोजिंदगी', 6, 1]]
# <class 'str'>

# %%
def get_top_users():
    conn = None
    try:
        conn = mysql.connector.connect(host='localhost', database='twitterbase', user='root', password='Dyq20150801@')
        cursor = conn.cursor()
        query = "SELECT NAME, FOLLOWERS_COUNT FROM user_info ORDER BY FOLLOWERS_COUNT DESC LIMIT 10"
        cursor.execute(query)
        results = cursor.fetchall()
        return [{'name': row[0], 'followers_count': row[1]} for row in results]
    except Error as e:
        print('Error while connecting to MySQL', e)
        
top_users = get_top_users()
if top_users:
    for user in top_users:
        print(user)
        
def get_top_tweets():
    try:
        client = pymongo.MongoClient('localhost', 27017)
        db = client.db 
        tweets_collection = db.tweets 


        try:
            tweets_collection.create_index([('favorite_count', pymongo.DESCENDING)])
        except pymongo.errors.OperationFailure as e:
            print(f"Error creating index: {e}")


        top_tweets = list(tweets_collection.find({}, {'_id': 0}).sort("favorite_count", pymongo.DESCENDING).limit(10))
        return top_tweets
    except pymongo.errors.PyMongoError as e:
        print(f"MongoDB error: {e}")
        return []


top_tweets = get_top_tweets()
if top_tweets:
    for tweet in top_tweets:
        print(tweet)
else:
    print("No tweets found or there's an error with the database connection.")
# Out:
# {'name': 'detikcom', 'followers_count': 15928061}
# {'name': 'J.K. Rowling', 'followers_count': 14608046}
# {'name': 'AajTak', 'followers_count': 9706667}
# {'name': 'ABP News', 'followers_count': 9563509}
# {'name': 'TIMES NOW', 'followers_count': 9499855}
# {'name': 'Rajdeep Sardesai', 'followers_count': 8947464}
# {'name': 'Le Monde', 'followers_count': 8808784}
# {'name': 'tvOneNews', 'followers_count': 8787649}
# {'name': 'Kompas.com', 'followers_count': 7678373}
# {'name': 'NTV', 'followers_count': 7429200}
# {'created_at': 'Fri Mar 13 00:43:40 +0000 2020', 'retweeted_id': 0, 'og_tweet_id': 1238264431320215553, 'text': '*corona virus enters my body*\n\nThe 4 Flintstone gummies I ate in 2005: https://t.co/3STfdIQtaT', 'screen_name': 'HtownBabyG', 'retweet_count': 237307, 'favorite_count': 811062, 'lang': 'en', 'quote_count': 6828, 'reply_count': 1811, 'media': 'http://pbs.twimg.com/ext_tw_video_thumb/1238264358150569986/pu/img/IqZsgAzo4VjQbUF3.jpg', 'hashtags': [], 'is_retweet': False}
# {'created_at': 'Fri Mar 27 13:43:00 +0000 2020', 'retweeted_id': 0, 'og_tweet_id': 1243533984371523584, 'text': 'Due to Corona, we officially have three days of the week\n\n1. Yesterday \n2. Today\n3. Tomorrow', 'screen_name': 'JennEngineer_', 'retweet_count': 107516, 'favorite_count': 369496, 'lang': 'en', 'quote_count': 1424, 'reply_count': 468, 'media': None, 'hashtags': [], 'is_retweet': False}
# {'created_at': 'Mon Mar 23 17:13:35 +0000 2020', 'retweeted_id': 0, 'og_tweet_id': 1242137430322446344, 'text': 'This is Dr. Usama Riaz. He spent past weeks screening and treating patients with Corona Virus in Pakistan. \n\nHe kne… https://t.co/gb8RYnLt3F', 'screen_name': '_SJPeace_', 'retweet_count': 119601, 'favorite_count': 331618, 'lang': 'en', 'quote_count': 5635, 'reply_count': 4876, 'media': None, 'hashtags': [], 'is_retweet': False}

# %%
@app.route("/")
def index():
    return render_template('index.html')

@app.route('/search/text', methods=['GET'])
def search_text():
    string = str(request.args.get('string'))
    limit = request.args.get('limit', type=int)
    start_time = str(request.args.get('start_time'))
    end_time = str(request.args.get('end_time'))

    result = main('text', string, limit, start_time, end_time)
    return jsonify(result)

@app.route('/search/hashtag', methods=['GET'])
def search_hashtag():
    string = str(request.args.get('string'))
    limit = request.args.get('limit', type=int)
    start_time = str(request.args.get('start_time'))
    end_time = str(request.args.get('end_time'))

    result = main('hashtag', string, limit, start_time, end_time)
    return jsonify(result)

@app.route('/search/user', methods=['GET'])
def search_user():
    string = str(request.args.get('string'))
    limit = request.args.get('limit', type=int)
    start_time = str(request.args.get('start_time'))
    end_time = str(request.args.get('end_time'))

    result = main('user', string, limit)
    return jsonify(result)

@app.route('/search/author', methods=['GET'])
def search_author():
    string = str(request.args.get('string'))
    result = main('author', string)  
    return jsonify(result)

@app.route('/search/retweet', methods=['GET'])
def search_retweet():
    string = str(request.args.get('string'))
    result = main('retweet', string)  
    return jsonify(result)

@app.route('/top_users', methods=['GET'])
def top_users():
    users = get_top_users()
    return jsonify(users)

@app.route('/top_tweets', methods=['GET'])
def top_tweets():
    tweets = get_top_tweets()
    return jsonify(tweets)

# %%
def search(search_type):
    string = str(request.args.get('string'))
    limit = request.args.get('limit', type=int)
    start_time = str(request.args.get('start_time'))
    end_time = str(request.args.get('end_time'))
    
    if search_type in ['text', 'hashtag', 'user']:
        result = main(search_type, string, limit, start_time, end_time)
        return jsonify(result)
    elif search_type in ['author', 'retweet']:
        result = main(search_type, string)
        return jsonify(result)
    else:
        return jsonify({'error': 'Invalid search type'})

# %%
if __name__ == "__main__":
    app.run(debug=True,use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# D:\Anaconda\lib\site-packages\werkzeug\serving.py:718: ResourceWarning: unclosed <socket.socket fd=1016, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0>
#   self.socket = socket.fromfd(fd, address_family, socket.SOCK_STREAM)
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - -

# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# 127.0.0.1 - - [26/Apr/2024 10:21:19] "GET /search/author?string=1 HTTP/1.1" 200 -
# []
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x178039fb280>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# 127.0.0.1 - - [26/Apr/2024 10:21:57] "GET /search/author?string=bablusharmabjp&limit=null&start_time=null&end_time=null HTTP/1.1" 200 -
# [['Sat Apr 18 04:20:02 +0000 2020', '*अंदर से कोई बाहर न जा सके*\n\n*बाहर से कोई अंदर न जा सके*\n\n*घर में रहे सेफ रहे*\n\n#corona  रूपी रावण को मारना है*\n\n#सुप्रभात #हेलोजिंदगी', 6, 1]]
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x178039fb2e0>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# 127.0.0.1 - - [26/Apr/2024 10:22:33] "GET /search/hashtag?string=trump&limit=5&start_time=12:00:00&end_time=12:10:00 HTTP/1.1" 200 -
# 12:00:0012:10:00trumpLIMIT5
# Going to tables
# Time taken: 206982900 seconds
# No results found
# 127.0.0.1 - - [26/Apr/2024 10:22:49] "GET /search/text?string=trump&limit=5&start_time=12:00:00&end_time=15:40:00 HTTP/1.1" 200 -
# 12:00:0015:40:00trumpLIMIT5
# found in Cache
# Time taken: -1.7141413673395566e+18 seconds
# [['Sat Apr 25 12:02:00 +0000 2020', 1254017815142490114, 'Presiden Amerika Serikat Donald Trump mengatakan telah menerima telepon dari Presiden Joko Widodo. \n\nPembicaraan te… https://t.co/SnywFBm8j0', 'KompasTV', 3, 13, 'in', 0, 1, None, [], False], ['Sat Apr 25 12:20:14 +0000 2020', 1254022403396636674, '@MarriedtoBringo Trump is on Twitter every single day, but even I mentioned Corona a week earlier than he did.', 'LabradorYuki', 1, 5, 'en', 0, 2, None, [], False], ['Sat Apr 25 12:02:59 +0000 2020', 1254018062694703106, 'The Trump Admin bought at least 29 mil doses of this poison and promoted it daily through press briefings, \u2066… https://t.co/rKrkvzJh3x', 'PassionFruit62', 4, 4, 'en', 0, 0, None, [], False], ['Sat Apr 25 12:02:21 +0000 2020', 1254017905769005056, '„Nur ein Idiot hätte jetzt keine Angst“, sagt Siri #Hustvedt zur #Coronakrise - und dass Donald #Trump ein Verrückt… https://t.co/b9VcGKL0NH', 'BerlinerNotizen', 3, 4, 'de', 0, 0, None, ['Hustvedt', 'Coronakrise', 'Trump'], False], ['Sat Apr 25 12:17:48 +0000 2020', 1254021793926524929, 'Der Clown 🤡 ihres Vertrauens empfiehlt. #Corona #Trump https://t.co/6sa7ZJqEM4', 'Aeskulappirat', 3, 4, 'de', 0, 0, 'http://pbs.twimg.com/media/EWct-sdXQAIkd_e.jpg', ['Corona', 'Trump'], False], ['Sat Apr 25 12:13:00 +0000 2020', 1254020583148281856, 'Groene-redacteur @Thomas_C_A schrijft vanuit Washington over het Amerika van Donald Trump. In aflevering 20: Trumps… https://t.co/D3WdmNM36E', 'DeGroene', 3, 4, 'nl', 0, 0, None, [], False], ['Sat Apr 25 12:17:04 +0000 2020', 1254021605635719168, 'Coronavirus task force adviser was shocked by Trump’s absurd claim: ‘I wanted to hide’ https://t.co/sYZLN9ZTee https://t.co/dzmdsFj2iK', 'Politics_PR', 2, 1, 'en', 1, 0, 'http://pbs.twimg.com/media/EWcuAT0UwAAen4y.jpg', [], False], ['Sat Apr 25 12:18: